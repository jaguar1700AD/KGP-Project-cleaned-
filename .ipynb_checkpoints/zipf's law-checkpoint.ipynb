# %%
import re
from operator import itemgetter
import matplotlib.pyplot as plt
from scipy import special
import numpy as np
import os
import sys
import bs4 as bs
import nltk

# %%
global_dir = 'D:\\KGP\\'

# %%
def removeNonAscii(text):
    out = ''
    for c in text:
        if ord(c) in range(128):
            out += c
    return out

# %%
def stripper(word, strip_list):
    for item in strip_list:
        word = word.strip(item)
    return word

# %%
#strip_list = ['.',',']

frequency = {}
bad_files = []

for index in range(1,10):
    directory = global_dir + "man" + str(index) + "\\"
    all_files = os.listdir(directory)
    n = 0
    for file in all_files:
        with open(directory + file, 'rb') as sauce:
            try:
                soup = bs.BeautifulSoup(sauce, 'lxml')
                #words = [stripper(each) for each in re.findall(r'(\b[^\b]{2,9}\b)', soup.get_text())]
                words = nltk.word_tokenize(soup.get_text())
                for word in words:
                    count = frequency.get(word,0)
                    frequency[word] = count + 1
                n += 1
                sys.stdout.flush()
                sys.stdout.write("Index : %d Progress: %d / %d / %d  \r" % (index, n, len(all_files), len(bad_files)) )
            except:
                bad_files.append(directory + file)
# Out:
# Index : 9 Progress: 408 / 408 / 0

# %%
frequency
# Out:
# {'Ubuntu': 376153,
#  'Manpage': 250206,
#  ':': 3941590,
#  'ion': 124,
#  '-': 596615,
#  'Interplanetary': 66,
#  'Overlay': 252,
#  'Network': 2624,
#  'tools': 11319,
#  ',': 14020165,
#  'the': 9696302,
#  'NASA': 239,
#  'implementation': 29616,
#  'of': 4970406,
#  'Delay-Tolerant': 65,
#  'Menu': 125898,
#  'Close': 126547,
#  'menu': 137744,
#  'Jump': 125355,
#  'to': 3213862,
#  'main': 148548,
#  'content': 141778,
#  'Provided': 125287,
#  'by': 1342902,
#  'ion_3.2.1+dfsg-1.1_amd64': 139,
#  'NAME': 139470,
#  'Networking': 1809,
#  '(': 6945620,
#  'DTN': 59,
#  ')': 6935146,
#  'DESCRIPTION': 109222,
#  'This': 776749,
#  'manual': 39197,
#  'page': 67838,
#  'documents': 8194,
#  'briefly': 2732,
#  'commands': 41230,
#  'distributed': 15279,
#  'with': 885448,
#  'suite': 4672,
#  '.': 9642163,
#  'was': 143940,
#  'written': 57345,
#  'for': 1557468,
#  'Debian': 18219,
#  'distribution': 22967,
#  'because': 50349,
#  'original': 56638,
#  'programs': 28662,
#  'do': 125482,
#  'not': 874848,
#  'have': 191503,
#  'pages': 17393,
#  'Concise': 47,
#  'synopsis': 938,
#  'can': 503962,
#  'be': 1354041,
#  'obtained': 21094,
#  'giving': 4872,
#  '-h': 22059,
#  'SYNOPSIS': 101155,
#  'aoslsi': 26,
#  'aoslso': 26,
#  'bsscounter': 26,
#  'bssdriver': 26,
#  'bsspcli': 26,
#  'bsspclo': 26,
#  'bsspclock': 27,
#  'dtnperf_vION': 26,
#  'file2tcp': 26,
#  'file2udp': 26,
#  'ionexit': 26,
#  'ionrestart': 26,
#  'ionscript': 26,
#  'ionstart': 26,
#  'ionstop': 26,
#  'ionwarn': 26,
#  'killm': 26,
#  'nm_agent': 26,
#  'nm_mgr': 26,
#  'sdatest': 26,
#  'tcp2file': 26,
#  'tcpbsi': 27,
#  'tcpbso': 29,
#  'udp2file': 26,
#  'udpbsi': 28,
#  'SEE': 75692,
#  'ALSO': 75627,
#  'bpadmin': 229,
#  '1': 979673,
#  'dtn2admin': 52,
#  'ltpadmin': 100,
#  'cfdpadmin': 62,
#  'ipnadmin': 58,
#  'ionadmin': 85,
#  'AUTHOR': 46377,
#  'Leo': 79,
#  'Iannacone': 30,
#  '<': 834333,
#  'l3on': 29,
#  '@': 165485,
#  'ubuntu.com': 418,
#  '>': 1460096,
#  'system': 138742,
#  'but': 191918,
#  'may': 298900,
#  'used': 471096,
#  'others': 14094,
#  'Permission': 4691,
#  'is': 4828078,
#  'granted': 5679,
#  'copy': 50419,
#  'distribute': 6452,
#  'and/or': 53979,
#  'modify': 31204,
#  'this': 663519,
#  'document': 23803,
#  'under': 52900,
#  'terms': 31963,
#  'GNU': 45329,
#  'General': 16098,
#  'Public': 16542,
#  'License': 31678,
#  'Version': 19268,
#  '2': 271258,
#  'any': 229501,
#  'later': 27787,
#  'version': 162328,
#  'published': 8122,
#  'Free': 16563,
#  'Software': 20667,
#  'Foundation': 11943,
#  'On': 419156,
#  'systems': 37281,
#  'complete': 33811,
#  'text': 64753,
#  'found': 65655,
#  'in': 2032065,
#  '/usr/share/common-licenses/GPL': 698,
#  'Powered': 124933,
#  'Repository': 125174,
#  'file': 615594,
#  'bugs': 146288,
#  'Launchpad': 125128,
#  '©': 134038,
#  '2019': 124945,
#  'Canonical': 375029,
#  'Ltd.': 125711,
#  'and': 2701225,
#  'are': 1056255,
#  'registered': 140171,
#  'trademarks': 124973,
#  'Ltd': 249569,
#  'file65': 9,
#  'print': 45600,
#  'information': 146049,
#  'o65': 11,
#  'object': 161881,
#  'files': 169451,
#  'xa65_2.3.8-2_amd64': 6,
#  '[': 760436,
#  'OPTION': 3757,
#  ']': 761051,
#  '...': 196864,
#  'FILE': 25249,
#  'prints': 10287,
#  'format': 204294,
#  'OPTIONS': 39614,
#  '-V': 8550,
#  'Print': 25451,
#  'undefined': 18709,
#  'global': 42375,
#  'labels': 6166,
#  '-P': 6280,
#  'segment': 11267,
#  'end': 48590,
#  'addresses': 22238,
#  'suitable': 18066,
#  'xa': 84,
#  'command': 164481,
#  'line': 138394,
#  'parameter': 98943,
#  '-b': 10276,
#  '-a': 12795,
#  'offset': 27401,
#  '``': 1068686,
#  'ROMmable': 1,
#  "''": 1119019,
#  'another': 31588,
#  'behind': 2451,
#  'one': 295270,
#  'same': 167570,
#  'ROM': 2283,
#  'located': 8835,
#  'at': 293892,
#  'specified': 239815,
#  '-A': 4667,
#  'Does': 2624,
#  'thing': 5119,
#  'as': 923273,
#  'only': 325123,
#  'starting': 25687,
#  'address': 103982,
#  'next': 38420,
#  '--': 1080039,
#  'help': 56048,
#  'Show': 16393,
#  'summary': 9126,
#  'options': 192202,
#  'program': 121489,
#  'ldo65': 9,
#  'printcbm': 9,
#  'reloc65': 11,
#  'uncpk': 13,
#  'dxa': 7,
#  'David': 3873,
#  'Weinehall': 17,
#  'tao': 35,
#  'acc.umu.se': 10,
#  'Cameron': 71,
#  'Kaiser': 63,
#  'ckaiser': 5,
#  'floodgap.com': 5,
#  'Original': 945,
#  'package': 46868,
#  'C': 330485,
#  '1989-1997': 6,
#  'Andre': 83,
#  'Fachat': 26,
#  'Additional': 4100,
#  'changes': 29697,
#  '1989-2006': 5,
#  'Jolse': 6,
#  'Maginnis': 6,
#  'The': 1937719,
#  'current': 118761,
#  'maintainer': 2299,
#  'WEBSITE': 179,
#  'http': 75742,
#  '//www.floodgap.com/retrotech/xa/': 6,
#  '11': 74898,
#  'April': 6551,
#  '2006': 3528,
#  'FILE65': 1,
#  'FileCheck': 197,
#  'Flexible': 198,
#  'pattern': 22130,
#  'matching': 21206,
#  'verifier': 159,
#  'llvm-3.8_3.8.1-27ubuntu1_amd64': 29,
#  'match-filename': 22,
#  '–check-prefix=XXX': 5,
#  '–strict-whitespace': 5,
#  'reads': 11840,
#  'two': 114160,
#  'from': 504918,
#  'standard': 91625,
#  'input': 156454,
#  'on': 696103,
#  'uses': 66178,
#  'verify': 7861,
#  'other': 141427,
#  'behavior': 38867,
#  'particularly': 2263,
#  'useful': 47104,
#  'testsuite': 444,
#  'which': 425689,
#  'wants': 2799,
#  'that': 938487,
#  'output': 203910,
#  'some': 99256,
#  'tool': 20520,
#  'e.g': 32799,
#  'llc': 184,
#  'contains': 175232,
#  'expected': 14952,
#  'example': 118032,
#  'a': 2663866,
#  'movsd': 5,
#  'esp': 228,
#  'or': 1292196,
#  'whatever': 4797,
#  'interesting': 2430,
#  'similar': 27727,
#  'using': 245962,
#  'grep': 2505,
#  'it': 516584,
#  'optimized': 5356,
#  'multiple': 51852,
#  'different': 57775,
#  'inputs': 2431,
#  'specific': 43283,
#  'order': 202744,
#  'specifies': 84086,
#  'patterns': 6537,
#  'match': 42150,
#  'read': 72722,
#  'unless': 33604,
#  'input-file': 670,
#  'option': 358230,
#  '-help': 3516,
#  'check-prefix': 14,
#  'prefix': 23930,
#  'searches': 5532,
#  'contents': 36349,
#  'By': 35438,
#  'default': 372182,
#  'these': 90664,
#  'prefixed': 3858,
#  '“': 21914,
#  'CHECK': 659,
#  '”': 22086,
#  'If': 769744,
#  'you': 309539,
#  '’': 26191,
#  'd': 41149,
#  'like': 70482,
#  'use': 376324,
#  'checking': 12956,
#  'argument': 220224,
#  'allows': 42129,
#  'specify': 71786,
#  'more': 151030,
#  'prefixes': 2455,
#  'Multiple': 7277,
#  'tests': 13787,
#  'might': 32104,
#  'change': 48778,
#  'run': 63231,
#  'most': 49306,
#  'lines': 34607,
#  'remain': 5204,
#  'filename': 40712,
#  'File': 15502,
#  'check': 42299,
#  'defaults': 23910,
#  'stdin': 6336,
#  'strict-whitespace': 14,
#  'canonicalizes': 20,
#  'horizontal': 5392,
#  'whitespace': 6950,
#  'spaces': 9056,
#  'tabs': 2547,
#  'causes': 21574,
#  'ignore': 8961,
#  'differences': 5493,
#  'space': 60320,
#  'will': 556368,
#  'tab': 5899,
#  'disables': 10364,
#  'End-of-line': 11,
#  'sequences': 13633,
#  'canonicalized': 141,
#  'UNIX-style': 89,
#  '\\n': 10181,
#  'all': 314067,
#  'modes': 15741,
#  'implicit-check-not': 10,
#  'check-pattern': 5,
#  'Adds': 2706,
#  'implicit': 8871,
#  'negative': 23883,
#  'checks': 18294,
#  'between': 86400,
#  'positive': 37836,
#  'writing': 15184,
#  'stricter': 168,
#  'without': 75839,
#  'stuffing': 20,
#  'them': 55281,
#  'CHECK-NOTs': 5,
#  'For': 201904,
#  'warning': 48575,
#  'when': 314710,
#  'testing': 7720,
#  'diagnostic': 4976,
#  'messages': 42482,
#  'don': 719,
#  't': 13171,
#  'an': 776448,
#  'clang': 182,
#  '-verify': 234,
#  'With': 23315,
#  'does': 149582,
#  'contain': 118114,
#  'warnings': 18675,
#  'covered': 2427,
#  '-version': 1733,
#  'number': 487318,
#  'EXIT': 2406,
#  'STATUS': 3271,
#  'verifies': 965,
#  'matches': 19108,
#  'exits': 6950,
#  '0': 940677,
#  'Otherwise': 24933,
#  'if': 1088237,
#  'error': 333888,
#  'occurs': 16845,
#  'exit': 368381,
#  'non-zero': 19709,
#  'value': 581531,
#  'TUTORIAL': 64,
#  'typically': 13950,
#  'LLVM': 1135,
#  'regression': 945,
#  'being': 59229,
#  'invoked': 17728,
#  'RUN': 269,
#  'test': 32534,
#  'A': 1374498,
#  'simple': 23611,
#  'looks': 7445,
#  ';': 1264813,
#  'llvm-as': 103,
#  '%': 130070,
#  's': 88803,
#  '|': 222562,
#  '-march=x86-64': 5,
#  'syntax': 22783,
#  'says': 1937,
#  'pipe': 5650,
#  'into': 131380,
#  'then': 304523,
#  'means': 43031,
#  'verifying': 968,
#  'its': 131416,
#  'against': 19762,
#  '.ll': 91,
#  'To': 82399,
#  'see': 127534,
#  'how': 41315,
#  'works': 18899,
#  'let': 16646,
#  'look': 15086,
#  'rest': 9388,
#  'after': 95445,
#  'define': 194862,
#  'void': 188628,
#  'sub1': 99,
#  'i32*': 25,
#  'p': 21383,
#  'i32': 233,
#  'v': 73878,
#  '{': 272397,
#  'entry': 285860,
#  'subl': 20,
#  '=': 3593068,
#  'tail': 10889,
#  'call': 138634,
#  'llvm.atomic.load.sub.i32.p0i32': 5,
#  'ret': 2920,
#  '}': 271414,
#  'inc4': 15,
#  'i64*': 10,
#  'incq': 5,
#  'i64': 246,
#  'llvm.atomic.load.add.i64.p0i64': 5,
#  'Here': 14723,
#  'comments': 15231,
#  'Now': 14160,
#  'piped': 509,
#  'machine': 30324,
#  'code': 233565,
#  'what': 41063,
#  'we': 45685,
#  'very': 33034,
#  'they': 77227,
#  'fixed': 12644,
#  'strings': 24699,
#  'must': 264937,
#  'occur': 21143,
#  'ignoring': 2325,
#  'allowed': 30156,
#  'otherwise': 78335,
#  'required': 54667,
#  'exactly': 25876,
#  'One': 22458,
#  'nice': 2613,
#  'about': 81342,
#  'compared': 4382,
#  'merging': 3480,
#  'cases': 40310,
#  'together': 18389,
#  'logical': 22438,
#  'groups': 9381,
#  'above': 95702,
#  'there': 75024,
#  'those': 45993,
#  'existed': 531,
#  'somewhere': 1857,
#  'else': 20605,
#  'would': 50977,
#  'count': 43120,
#  'exists': 16668,
#  'anywhere': 2639,
#  '-check-prefix': 10,
#  'configurations': 7328,
#  'driven': 607,
#  'many': 34630,
#  'circumstances': 2373,
#  'architectural': 109,
#  'variants': 3639,
#  '-mtriple=i686-apple-darwin9': 5,
#  '-mattr=sse41': 10,
#  '\\': 38215,
#  '-check-prefix=X32': 5,
#  '-mtriple=x86_64-apple-darwin9': 5,
#  '-check-prefix=X64': 5,
#  '4': 88527,
#  'x': 129512,
#  'pinsrd_1': 15,
#  'tmp': 1397,
#  'nounwind': 5,
#  'tmp1': 10,
#  'insertelement': 10,
#  'X32': 10,
#  'pinsrd': 10,
#  '$': 651423,
#  'xmm0': 27,
#  'X64': 13,
#  'edi': 99,
#  'In': 114664,
#  'case': 93509,
#  're': 1555,
#  'get': 55419,
#  'generation': 18020,
#  'both': 72893,
#  '32-bit': 27767,
#  '64-bit': 16056,
#  'CHECK-NEXT': 60,
#  'directive': 11747,
#  'Sometimes': 1676,
#  'want': 41237,
#  'happen': 6938,
#  'consecutive': 10788,
#  'no': 236800,
#  'directives': 9162,
#  'custom': 8991,
#  'just': 55284,
#  'PREFIX': 907,
#  '-NEXT': 5,
#  'something': 11788,
#  'expect': 5445,
#  't2': 706,
#  'double': 240934,
#  '*': 1074666,
#  'r': 14040,
#  'B': 395127,
#  'tmp3': 10,
#  'load': 27118,
#  'align': 2745,
#  '16': 19388,
#  'tmp7': 10,
#  'undef': 16947,
#  'tmp9': 13,
#  'shufflevector': 5,
#  'store': 30573,
#  'movl': 94,
#  '8': 66874,
#  'eax': 303,
#  'movapd': 10,
#  'movhpd': 10,
#  '12': 53630,
#  'reject': 2297,
#  'newline': 6921,
#  'previous': 42886,
#  'first': 256578,
#  'CHECK-SAME': 30,
#  '-SAME': 5,
#  'powerful': 1180,
#  'conjunction': 7598,
#  'CHECK-NOT': 49,
#  'described': 37487,
#  'below': 76991,
#  'following': 125579,
#  '!': 58246,
#  'DILocation': 10,
#  '5': 91393,
#  'scope': 8713,
#  'inlinedAt': 5,
#  'column': 120436,
#  'SCOPE': 101,
#  '0-9': 1103,
#  '+': 145903,
#  'newlines': 1896,
#  'string': 184581,
#  'doesn': 512,
#  'before': 86286,
#  'last': 86705,
#  'removed': 22245,
#  'transformation': 26089,
#  'i8': 157,
#  'coerce_offset0': 10,
#  'V': 195689,
#  'P': 125810,
#  'P2': 16749,
#  'bitcast': 15,
#  'i8*': 15,
#  'P3': 76,
#  'getelementptr': 5,
#  'CHECK-DAG': 100,
#  'necessary': 21021,
#  'strictly': 25112,
#  'sequential': 2152,
#  'could': 38778,
#  'emits': 1789,
#  'vtable': 868,
#  'globals': 1506,
#  'reverse': 8936,
#  'Using': 12325,
#  'keep': 11356,
#  'natural': 2096,
#  '//': 15023,
#  'clang_cc1': 5,
#  '-emit-llvm': 14,
#  '-o': 20813,
#  'struct': 101041,
#  'Foo': 2970,
#  'virtual': 22779,
#  'method': 90818,
#  'f': 18871,
#  'emit': 6760,
#  '_ZTV3Foo': 5,
#  'Bar': 751,
#  'b': 48952,
#  '_ZTV3Bar': 5,
#  'mixed': 2235,
#  'exclude': 4706,
#  'surrounding': 2007,
#  'As': 19848,
#  'result': 69739,
#  'reordered': 8400,
#  'i.e': 31497,
#  'occurrences': 1083,
#  'fall': 3569,
#  'BEFORE': 249,
#  'NOT': 20056,
#  'AFTER': 235,
#  'where': 236135,
#  'captured': 1798,
#  'variables': 45062,
#  'able': 14736,
#  'valid': 42145,
#  'topological': 193,
#  'orderings': 64,
#  'DAG': 236,
#  'edges': 2721,
#  'definition': 15465,
#  'variable': 91704,
#  'It': 157778,
#  'e.g.': 11399,
#  'your': 92345,
#  'need': 55796,
#  'instruction': 39734,
#  'scheduler': 3646,
#  'add': 37978,
#  'REG1': 11,
#  'r1': 552,
#  'r2': 1052,
#  'REG2': 31,
#  'r3': 77,
#  'r4': 51,
#  'mul': 520,
#  'r5': 246,
#  'instructions': 71872,
#  'defining': 6727,
#  'block': 195032,
#  'aware': 3787,
#  'rule': 13113,
#  'So': 9036,
#  'instance': 33752,
#  'pass': 39535,
#  'vmov.32': 40,
#  'd0': 250,
#  'While': 9460,
#  'd1': 732,
#  'also': 197761,
#  'dangerous': 1100,
#  'register': 39994,
#  'sequence': 50441,
#  'strong': 1281,
#  'write': 45908,
#  'etc': 20498,
#  'looking': 5113,
#  'bug': 13786,
#  'compiler': 72687,
#  'further': 33509,
#  'away': 5863,
#  'mask': 14201,
#  'real': 294317,
#  'enforce': 1919,
#  'non-DAG': 6,
#  'DAG-blocks': 5,
#  'CHECK-LABEL': 46,
#  'containing': 41178,
#  'divided': 6098,
#  'blocks': 56840,
#  'inadvertently': 574,
#  'succeed': 2242,
#  'usually': 32601,
#  'eventually': 1665,
#  'generated': 49904,
#  'flagged': 1251,
#  'causing': 3306,
#  'actually': 21252,
#  'bear': 286,
#  'relationship': 1726,
#  'actual': 17276,
#  'source': 98799,
#  'problem': 39544,
#  'produce': 12247,
#  'better': 12167,
#  'treated': 13711,
#  'identically': 1430,
#  'normal': 26847,
#  'except': 42282,
#  'makes': 27409,
#  'additional': 30896,
#  'assumption': 1931,
#  'matched': 7234,
#  'present': 27215,
#  'intended': 14202,
#  'unique': 13075,
#  'identifiers': 4605,
#  'Conceptually': 178,
#  'presence': 3157,
#  'divides': 1215,
#  'stream': 54992,
#  'separate': 22182,
#  'each': 167184,
#  'processed': 14387,
#  'independently': 2666,
#  'preventing': 952,
#  'struct.C*': 25,
#  'C_ctor_base': 15,
#  'mov': 259,
#  'SAVETHIS': 10,
#  'r0': 282,
#  'bl': 1010,
#  'A_ctor_base': 10,
#  'struct.A*': 15,
#  'struct.B*': 15,
#  'call2': 5,
#  'B_ctor_base': 5,
#  'struct.D*': 10,
#  'D_ctor_base': 10,
#  'ensures': 2763,
#  'three': 68224,
#  'accept': 12108,
#  'corresponding': 82221,
#  'body': 10077,
#  'function': 340365,
#  'even': 55951,
#  'Furthermore': 2278,
#  'fail': 17202,
#  'recover': 1095,
#  'continuing': 600,
#  'allowing': 5135,
#  'failures': 2586,
#  'detected': 10406,
#  'single': 63382,
#  'invocation': 3835,
#  'There': 32792,
#  'requirement': 5922,
#  'correspond': 10307,
#  'syntactic': 536,
#  'language': 22377,
#  'simply': 13840,
#  'uniquely': 1085,
#  'verified': 1619,
#  'definitions': 9196,
#  'Pattern': 734,
#  'Matching': 447,
#  'Syntax': 4537,
#  'All': 42516,
#  'take': 24322,
#  'perfectly': 621,
#  'sufficient': 4770,
#  'things': 10483,
#  'flexible': 2407,
#  'form': 174905,
#  'desired': 25494,
#  'support': 81057,
#  'regular': 16773,
#  'expressions': 12824,
#  'surrounded': 737,
#  'braces': 1441,
#  'yourregex': 5,
#  'Because': 7107,
#  'majority': 912,
#  'has': 262432,
#  'been': 136468,
#  'designed': 7968,
#  'mixing': 987,
#  'xmm': 14,
#  '0-7': 299,
#  'ESP': 287,
#  'enclosed': 2122,
#  'visually': 372,
#  'distinct': 2367,
#  'escape': 6442,
#  'characters': 57190,
#  'within': 47506,
#  'C.': 53277,
#  'rare': 2537,
#  'explicitly': 23566,
#  'ugly': 382,
#  'Variables': 3200,
#  'often': 11020,
#  'again': 12836,
#  'codegen': 22,
#  'allow': 28406,
#  'consistently': 520,
#  'named': 29554,
#  'defined': 117536,
#  'substituted': 1640,
#  'test5': 12,
#  'notw': 5,
#  'REGISTER': 121,
#  'a-z': 449,
#  'andw': 10,
#  'regex': 4280,
#  'captures': 560,
#  'second': 49053,
#  'references': 16614,
#  'always': 53106,
#  'contained': 9954,
#  'pairs': 14682,
#  'their': 54284,
#  'names': 66075,
#  'formed': 8258,
#  'a-zA-Z': 79,
#  'a-zA-Z0-9': 40,
#  'colon': 4562,
#  'follows': 69411,
#  'name': 237906,
#  'times': 30335,
#  'latest': 6411,
#  'were': 52320,
#  'op': 19101,
#  'REG': 52,
#  'Can': 7117,
#  'operands': 2552,
#  'care': 5109,
#  'Expressions': 607,
#  'refers': 5752,
#  'numbers': 47351,
#  'diagnostics': 3118,
#  'introduces': 1336,
#  'certain': 19254,
#  'fragility': 6,
#  'structure': 84293,
#  'absolute': 36663,
#  'updated': 30877,
#  'whenever': 10504,
#  'due': 15612,
#  'addition': 18309,
#  'deletion': 1371,
#  'LINE': 1808,
#  'LINE+': 5,
#  'LINE-': 5,
#  'These': 64581,
#  'expand': 3002,
#  'optional': 36060,
#  'integer': 751475,
#  'way': 40792,
#  'put': 16868,
#  'near': 3833,
#  'relevant': 7481,
#  'include': 87935,
#  'relative': 51961,
#  'test.cpp': 8,
#  'LINE+4': 5,
#  ':6': 25,
#  "'": 2423547,
#  'top': 25398,
#  'level': 59856,
#  'declarator': 58,
#  '^int': 5,
#  '^': 5930,
#  '\\^': 98,
#  'int': 403168,
#  'Maintained': 264,
#  'Team': 2693,
#  '//llvm.org/': 129,
#  'COPYRIGHT': 35738,
#  '2003-2017': 83,
#  'Project': 5339,
#  'llvm-3.9_3.9.1-19ubuntu1_amd64': 29,
#  'check-prefixes': 4,
#  'prefix1': 20,
#  'prefix2': 24,
#  'An': 49529,
#  'alias': 14750,
#  'comma': 5432,
#  'separated': 16981,
#  'list': 177311,
#  'match-full-lines': 4,
#  'require': 19047,
#  'cover': 1728,
#  'entire': 12670,
#  'Leading': 1223,
#  'trailing': 9546,
#  'ignored': 31353,
#  'Note': 139547,
#  'affected': 4463,
#  'Passing': 3410,
#  'equivalent': 35062,
#  'inserting': 1224,
#  'every': 23560,
#  'Newline': 251,
#  'Characters': 792,
#  'character': 239689,
#  'class': 80990,
#  'DW_AT_location': 8,
#  'DW_FORM_sec_offset': 8,
#  'DLOC:0x': 4,
#  '0-9a-f': 55,
#  'intd': 15,
#  'llvm-dwarfdump': 47,
#  '0x00000233': 8,
#  'DW_AT_name': 6,
#  'DW_FORM_strp': 4,
#  '.debug_str': 82,
#  '0x000000c9': 4,
#  'letting': 521,
#  'us': 5053,
#  'set': 354970,
#  'DLOC': 4,
#  'extracted': 3585,
#  'immediately': 17496,
#  'preceding': 3406,
#  'llvm-4.0_4.0.1-10_amd64': 29,
#  '2003-2018': 979,
#  'llvm-5.0_5.0.1-4_amd64': 29,
#  'enable-var-scope': 6,
#  'Enables': 8054,
#  'start': 39726,
#  'considered': 18919,
#  'throughout': 867,
#  'encountered': 11906,
#  'effect': 37582,
#  'local': 47220,
#  'cleared': 3774,
#  'beginning': 13470,
#  'Global': 3177,
#  'easier': 3328,
#  'ensure': 12682,
#  'individual': 10800,
#  'llvm-6.0_6.0-1ubuntu2_amd64': 54,
#  '-D': 8675,
#  'VAR=VALUE': 19,
#  'Sets': 19028,
#  'filecheck': 14,
#  'VAR': 492,
#  'VALUE': 13188,
#  'implements': 6848,
#  'POSIX': 10824,
#  'expression': 28033,
#  'matcher': 265,
#  'supports': 31359,
#  'Extended': 19715,
#  'ERE': 80,
#  'a-zA-Z_': 9,
#  'a-zA-Z0-9_': 35,
#  'forensics-colorize': 15,
#  'show': 19855,
#  'color': 40188,
#  'graphics': 7511,
#  'forensics-colorize_1.1-2_amd64': 3,
#  'filecompare': 21,
#  'size': 184977,
#  'bkmgpe': 3,
#  '-Vh': 12,
#  'FILE1': 131,
#  'FILE2': 131,
#  'colorize': 751,
#  '-h|-V': 10,
#  '-w': 8086,
#  'num': 13288,
#  '-ovd': 3,
#  'FILES': 9675,
#  'compare': 7205,
#  'large': 27293,
#  'filesystem': 20373,
#  'images': 14819,
#  'creating': 11947,
#  'intuitive': 301,
#  'produced': 9915,
#  'provide': 26813,
#  'quick': 2048,
#  'perfect': 571,
#  'sense': 6488,
#  'percentage': 5358,
#  'Comparing': 96,
#  'textual': 1768,
#  'diff': 5380,
#  'big': 4178,
#  'confusion': 1183,
#  ...}

# %%
import csv
bad_words = []
with open(global_dir + 'word_freq.txt','w') as csv_file:
    fieldnames = ['word','freq']
    csv_writer = csv.DictWriter(csv_file, fieldnames = fieldnames, delimiter = '\t')
    csv_writer.writeheader()

    for word in frequency:
        try:
            new_dict = {'word': word, 'freq' : frequency[word]}
            csv_writer.writerow(new_dict)
        except:
            bad_words.append(word)

# %%
len(bad_words)
# Out:
# 23535

# %%
frequency = {}
import csv
with open(global_dir + 'word_freq.txt','r') as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter = '\t')
    for word in csv_reader:
        frequency[word['word']] = word['freq']

# %%
for key, value in frequency.items():
    frequency[key] = int(value)
frequency
# Out:
# {'Ubuntu': 376153,
#  'Manpage': 250206,
#  ':': 3941590,
#  'ion': 124,
#  '-': 596615,
#  'Interplanetary': 66,
#  'Overlay': 252,
#  'Network': 2624,
#  'tools': 11319,
#  ',': 14020165,
#  'the': 9696302,
#  'NASA': 239,
#  'implementation': 29616,
#  'of': 4970406,
#  'Delay-Tolerant': 65,
#  'Menu': 125898,
#  'Close': 126547,
#  'menu': 137744,
#  'Jump': 125355,
#  'to': 3213862,
#  'main': 148548,
#  'content': 141778,
#  'Provided': 125287,
#  'by': 1342902,
#  'ion_3.2.1+dfsg-1.1_amd64': 139,
#  'NAME': 139470,
#  'Networking': 1809,
#  '(': 6945620,
#  'DTN': 59,
#  ')': 6935146,
#  'DESCRIPTION': 109222,
#  'This': 776749,
#  'manual': 39197,
#  'page': 67838,
#  'documents': 8194,
#  'briefly': 2732,
#  'commands': 41230,
#  'distributed': 15279,
#  'with': 885448,
#  'suite': 4672,
#  '.': 9642163,
#  'was': 143940,
#  'written': 57345,
#  'for': 1557468,
#  'Debian': 18219,
#  'distribution': 22967,
#  'because': 50349,
#  'original': 56638,
#  'programs': 28662,
#  'do': 125482,
#  'not': 874848,
#  'have': 191503,
#  'pages': 17393,
#  'Concise': 47,
#  'synopsis': 938,
#  'can': 503962,
#  'be': 1354041,
#  'obtained': 21094,
#  'giving': 4872,
#  '-h': 22059,
#  'SYNOPSIS': 101155,
#  'aoslsi': 26,
#  'aoslso': 26,
#  'bsscounter': 26,
#  'bssdriver': 26,
#  'bsspcli': 26,
#  'bsspclo': 26,
#  'bsspclock': 27,
#  'dtnperf_vION': 26,
#  'file2tcp': 26,
#  'file2udp': 26,
#  'ionexit': 26,
#  'ionrestart': 26,
#  'ionscript': 26,
#  'ionstart': 26,
#  'ionstop': 26,
#  'ionwarn': 26,
#  'killm': 26,
#  'nm_agent': 26,
#  'nm_mgr': 26,
#  'sdatest': 26,
#  'tcp2file': 26,
#  'tcpbsi': 27,
#  'tcpbso': 29,
#  'udp2file': 26,
#  'udpbsi': 28,
#  'SEE': 75692,
#  'ALSO': 75627,
#  'bpadmin': 229,
#  '1': 979673,
#  'dtn2admin': 52,
#  'ltpadmin': 100,
#  'cfdpadmin': 62,
#  'ipnadmin': 58,
#  'ionadmin': 85,
#  'AUTHOR': 46377,
#  'Leo': 79,
#  'Iannacone': 30,
#  '<': 834333,
#  'l3on': 29,
#  '@': 165485,
#  'ubuntu.com': 418,
#  '>': 1460096,
#  'system': 138742,
#  'but': 191918,
#  'may': 298900,
#  'used': 471096,
#  'others': 14094,
#  'Permission': 4691,
#  'is': 4828078,
#  'granted': 5679,
#  'copy': 50419,
#  'distribute': 6452,
#  'and/or': 53979,
#  'modify': 31204,
#  'this': 663519,
#  'document': 23803,
#  'under': 52900,
#  'terms': 31963,
#  'GNU': 45329,
#  'General': 16098,
#  'Public': 16542,
#  'License': 31678,
#  'Version': 19268,
#  '2': 271258,
#  'any': 229501,
#  'later': 27787,
#  'version': 162328,
#  'published': 8122,
#  'Free': 16563,
#  'Software': 20667,
#  'Foundation': 11943,
#  'On': 419156,
#  'systems': 37281,
#  'complete': 33811,
#  'text': 64753,
#  'found': 65655,
#  'in': 2032065,
#  '/usr/share/common-licenses/GPL': 698,
#  'Powered': 124933,
#  'Repository': 125174,
#  'file': 615594,
#  'bugs': 146288,
#  'Launchpad': 125128,
#  '©': 134038,
#  '2019': 124945,
#  'Canonical': 375029,
#  'Ltd.': 125711,
#  'and': 2701225,
#  'are': 1056255,
#  'registered': 140171,
#  'trademarks': 124973,
#  'Ltd': 249569,
#  'file65': 9,
#  'print': 45600,
#  'information': 146049,
#  'o65': 11,
#  'object': 161881,
#  'files': 169451,
#  'xa65_2.3.8-2_amd64': 6,
#  '[': 760436,
#  'OPTION': 3757,
#  ']': 761051,
#  '...': 196864,
#  'FILE': 25249,
#  'prints': 10287,
#  'format': 204294,
#  'OPTIONS': 39614,
#  '-V': 8550,
#  'Print': 25451,
#  'undefined': 18709,
#  'global': 42375,
#  'labels': 6166,
#  '-P': 6280,
#  'segment': 11267,
#  'end': 48590,
#  'addresses': 22238,
#  'suitable': 18066,
#  'xa': 84,
#  'command': 164481,
#  'line': 138394,
#  'parameter': 98943,
#  '-b': 10276,
#  '-a': 12795,
#  'offset': 27401,
#  '``': 1068686,
#  'ROMmable': 1,
#  "''": 1119019,
#  'another': 31588,
#  'behind': 2451,
#  'one': 295270,
#  'same': 167570,
#  'ROM': 2283,
#  'located': 8835,
#  'at': 293892,
#  'specified': 239815,
#  '-A': 4667,
#  'Does': 2624,
#  'thing': 5119,
#  'as': 923273,
#  'only': 325123,
#  'starting': 25687,
#  'address': 103982,
#  'next': 38420,
#  '--': 1080039,
#  'help': 56048,
#  'Show': 16393,
#  'summary': 9126,
#  'options': 192202,
#  'program': 121489,
#  'ldo65': 9,
#  'printcbm': 9,
#  'reloc65': 11,
#  'uncpk': 13,
#  'dxa': 7,
#  'David': 3873,
#  'Weinehall': 17,
#  'tao': 35,
#  'acc.umu.se': 10,
#  'Cameron': 71,
#  'Kaiser': 63,
#  'ckaiser': 5,
#  'floodgap.com': 5,
#  'Original': 945,
#  'package': 46868,
#  'C': 330485,
#  '1989-1997': 6,
#  'Andre': 83,
#  'Fachat': 26,
#  'Additional': 4100,
#  'changes': 29697,
#  '1989-2006': 5,
#  'Jolse': 6,
#  'Maginnis': 6,
#  'The': 1937719,
#  'current': 118761,
#  'maintainer': 2299,
#  'WEBSITE': 179,
#  'http': 75742,
#  '//www.floodgap.com/retrotech/xa/': 6,
#  '11': 74898,
#  'April': 6551,
#  '2006': 3528,
#  'FILE65': 1,
#  'FileCheck': 197,
#  'Flexible': 198,
#  'pattern': 22130,
#  'matching': 21206,
#  'verifier': 159,
#  'llvm-3.8_3.8.1-27ubuntu1_amd64': 29,
#  'match-filename': 22,
#  '–check-prefix=XXX': 5,
#  '–strict-whitespace': 5,
#  'reads': 11840,
#  'two': 114160,
#  'from': 504918,
#  'standard': 91625,
#  'input': 156454,
#  'on': 696103,
#  'uses': 66178,
#  'verify': 7861,
#  'other': 141427,
#  'behavior': 38867,
#  'particularly': 2263,
#  'useful': 47104,
#  'testsuite': 444,
#  'which': 425689,
#  'wants': 2799,
#  'that': 938487,
#  'output': 203910,
#  'some': 99256,
#  'tool': 20520,
#  'e.g': 32799,
#  'llc': 184,
#  'contains': 175232,
#  'expected': 14952,
#  'example': 118032,
#  'a': 2663866,
#  'movsd': 5,
#  'esp': 228,
#  'or': 1292196,
#  'whatever': 4797,
#  'interesting': 2430,
#  'similar': 27727,
#  'using': 245962,
#  'grep': 2505,
#  'it': 516584,
#  'optimized': 5356,
#  'multiple': 51852,
#  'different': 57775,
#  'inputs': 2431,
#  'specific': 43283,
#  'order': 202744,
#  'specifies': 84086,
#  'patterns': 6537,
#  'match': 42150,
#  'read': 72722,
#  'unless': 33604,
#  'input-file': 670,
#  'option': 358230,
#  '-help': 3516,
#  'check-prefix': 14,
#  'prefix': 23930,
#  'searches': 5532,
#  'contents': 36349,
#  'By': 35438,
#  'default': 372182,
#  'these': 90664,
#  'prefixed': 3858,
#  '“': 21914,
#  'CHECK': 659,
#  '”': 22086,
#  'If': 769744,
#  'you': 309539,
#  '’': 26191,
#  'd': 41149,
#  'like': 70482,
#  'use': 376324,
#  'checking': 12956,
#  'argument': 220224,
#  'allows': 42129,
#  'specify': 71786,
#  'more': 151030,
#  'prefixes': 2455,
#  'Multiple': 7277,
#  'tests': 13787,
#  'might': 32104,
#  'change': 48778,
#  'run': 63231,
#  'most': 49306,
#  'lines': 34607,
#  'remain': 5204,
#  'filename': 40712,
#  'File': 15502,
#  'check': 42299,
#  'defaults': 23910,
#  'stdin': 6336,
#  'strict-whitespace': 14,
#  'canonicalizes': 20,
#  'horizontal': 5392,
#  'whitespace': 6950,
#  'spaces': 9056,
#  'tabs': 2547,
#  'causes': 21574,
#  'ignore': 8961,
#  'differences': 5493,
#  'space': 60320,
#  'will': 556368,
#  'tab': 5899,
#  'disables': 10364,
#  'End-of-line': 11,
#  'sequences': 13633,
#  'canonicalized': 141,
#  'UNIX-style': 89,
#  '\\n': 10181,
#  'all': 314067,
#  'modes': 15741,
#  'implicit-check-not': 10,
#  'check-pattern': 5,
#  'Adds': 2706,
#  'implicit': 8871,
#  'negative': 23883,
#  'checks': 18294,
#  'between': 86400,
#  'positive': 37836,
#  'writing': 15184,
#  'stricter': 168,
#  'without': 75839,
#  'stuffing': 20,
#  'them': 55281,
#  'CHECK-NOTs': 5,
#  'For': 201904,
#  'warning': 48575,
#  'when': 314710,
#  'testing': 7720,
#  'diagnostic': 4976,
#  'messages': 42482,
#  'don': 719,
#  't': 13171,
#  'an': 776448,
#  'clang': 182,
#  '-verify': 234,
#  'With': 23315,
#  'does': 149582,
#  'contain': 118114,
#  'warnings': 18675,
#  'covered': 2427,
#  '-version': 1733,
#  'number': 487318,
#  'EXIT': 2406,
#  'STATUS': 3271,
#  'verifies': 965,
#  'matches': 19108,
#  'exits': 6950,
#  '0': 940677,
#  'Otherwise': 24933,
#  'if': 1088237,
#  'error': 333888,
#  'occurs': 16845,
#  'exit': 368381,
#  'non-zero': 19709,
#  'value': 581531,
#  'TUTORIAL': 64,
#  'typically': 13950,
#  'LLVM': 1135,
#  'regression': 945,
#  'being': 59229,
#  'invoked': 17728,
#  'RUN': 269,
#  'test': 32534,
#  'A': 1374498,
#  'simple': 23611,
#  'looks': 7445,
#  ';': 1264813,
#  'llvm-as': 103,
#  '%': 130070,
#  's': 88803,
#  '|': 222562,
#  '-march=x86-64': 5,
#  'syntax': 22783,
#  'says': 1937,
#  'pipe': 5650,
#  'into': 131380,
#  'then': 304523,
#  'means': 43031,
#  'verifying': 968,
#  'its': 131416,
#  'against': 19762,
#  '.ll': 91,
#  'To': 82399,
#  'see': 127534,
#  'how': 41315,
#  'works': 18899,
#  'let': 16646,
#  'look': 15086,
#  'rest': 9388,
#  'after': 95445,
#  'define': 194862,
#  'void': 188628,
#  'sub1': 99,
#  'i32*': 25,
#  'p': 21383,
#  'i32': 233,
#  'v': 73878,
#  '{': 272397,
#  'entry': 285860,
#  'subl': 20,
#  '=': 3593068,
#  'tail': 10889,
#  'call': 138634,
#  'llvm.atomic.load.sub.i32.p0i32': 5,
#  'ret': 2920,
#  '}': 271414,
#  'inc4': 15,
#  'i64*': 10,
#  'incq': 5,
#  'i64': 246,
#  'llvm.atomic.load.add.i64.p0i64': 5,
#  'Here': 14723,
#  'comments': 15231,
#  'Now': 14160,
#  'piped': 509,
#  'machine': 30324,
#  'code': 233565,
#  'what': 41063,
#  'we': 45685,
#  'very': 33034,
#  'they': 77227,
#  'fixed': 12644,
#  'strings': 24699,
#  'must': 264937,
#  'occur': 21143,
#  'ignoring': 2325,
#  'allowed': 30156,
#  'otherwise': 78335,
#  'required': 54667,
#  'exactly': 25876,
#  'One': 22458,
#  'nice': 2613,
#  'about': 81342,
#  'compared': 4382,
#  'merging': 3480,
#  'cases': 40310,
#  'together': 18389,
#  'logical': 22438,
#  'groups': 9381,
#  'above': 95702,
#  'there': 75024,
#  'those': 45993,
#  'existed': 531,
#  'somewhere': 1857,
#  'else': 20605,
#  'would': 50977,
#  'count': 43120,
#  'exists': 16668,
#  'anywhere': 2639,
#  '-check-prefix': 10,
#  'configurations': 7328,
#  'driven': 607,
#  'many': 34630,
#  'circumstances': 2373,
#  'architectural': 109,
#  'variants': 3639,
#  '-mtriple=i686-apple-darwin9': 5,
#  '-mattr=sse41': 10,
#  '\\': 38215,
#  '-check-prefix=X32': 5,
#  '-mtriple=x86_64-apple-darwin9': 5,
#  '-check-prefix=X64': 5,
#  '4': 88527,
#  'x': 129512,
#  'pinsrd_1': 15,
#  'tmp': 1397,
#  'nounwind': 5,
#  'tmp1': 10,
#  'insertelement': 10,
#  'X32': 10,
#  'pinsrd': 10,
#  '$': 651423,
#  'xmm0': 27,
#  'X64': 13,
#  'edi': 99,
#  'In': 114664,
#  'case': 93509,
#  're': 1555,
#  'get': 55419,
#  'generation': 18020,
#  'both': 72893,
#  '32-bit': 27767,
#  '64-bit': 16056,
#  'CHECK-NEXT': 60,
#  'directive': 11747,
#  'Sometimes': 1676,
#  'want': 41237,
#  'happen': 6938,
#  'consecutive': 10788,
#  'no': 236800,
#  'directives': 9162,
#  'custom': 8991,
#  'just': 55284,
#  'PREFIX': 907,
#  '-NEXT': 5,
#  'something': 11788,
#  'expect': 5445,
#  't2': 706,
#  'double': 240934,
#  '*': 1074666,
#  'r': 14040,
#  'B': 395127,
#  'tmp3': 10,
#  'load': 27118,
#  'align': 2745,
#  '16': 19388,
#  'tmp7': 10,
#  'undef': 16947,
#  'tmp9': 13,
#  'shufflevector': 5,
#  'store': 30573,
#  'movl': 94,
#  '8': 66874,
#  'eax': 303,
#  'movapd': 10,
#  'movhpd': 10,
#  '12': 53630,
#  'reject': 2297,
#  'newline': 6921,
#  'previous': 42886,
#  'first': 256578,
#  'CHECK-SAME': 30,
#  '-SAME': 5,
#  'powerful': 1180,
#  'conjunction': 7598,
#  'CHECK-NOT': 49,
#  'described': 37487,
#  'below': 76991,
#  'following': 125579,
#  '!': 58246,
#  'DILocation': 10,
#  '5': 91393,
#  'scope': 8713,
#  'inlinedAt': 5,
#  'column': 120436,
#  'SCOPE': 101,
#  '0-9': 1103,
#  '+': 145903,
#  'newlines': 1896,
#  'string': 184581,
#  'doesn': 512,
#  'before': 86286,
#  'last': 86705,
#  'removed': 22245,
#  'transformation': 26089,
#  'i8': 157,
#  'coerce_offset0': 10,
#  'V': 195689,
#  'P': 125810,
#  'P2': 16749,
#  'bitcast': 15,
#  'i8*': 15,
#  'P3': 76,
#  'getelementptr': 5,
#  'CHECK-DAG': 100,
#  'necessary': 21021,
#  'strictly': 25112,
#  'sequential': 2152,
#  'could': 38778,
#  'emits': 1789,
#  'vtable': 868,
#  'globals': 1506,
#  'reverse': 8936,
#  'Using': 12325,
#  'keep': 11356,
#  'natural': 2096,
#  '//': 15023,
#  'clang_cc1': 5,
#  '-emit-llvm': 14,
#  '-o': 20813,
#  'struct': 101041,
#  'Foo': 2970,
#  'virtual': 22779,
#  'method': 90818,
#  'f': 18871,
#  'emit': 6760,
#  '_ZTV3Foo': 5,
#  'Bar': 751,
#  'b': 48952,
#  '_ZTV3Bar': 5,
#  'mixed': 2235,
#  'exclude': 4706,
#  'surrounding': 2007,
#  'As': 19848,
#  'result': 69739,
#  'reordered': 8400,
#  'i.e': 31497,
#  'occurrences': 1083,
#  'fall': 3569,
#  'BEFORE': 249,
#  'NOT': 20056,
#  'AFTER': 235,
#  'where': 236135,
#  'captured': 1798,
#  'variables': 45062,
#  'able': 14736,
#  'valid': 42145,
#  'topological': 193,
#  'orderings': 64,
#  'DAG': 236,
#  'edges': 2721,
#  'definition': 15465,
#  'variable': 91704,
#  'It': 157778,
#  'e.g.': 11399,
#  'your': 92345,
#  'need': 55796,
#  'instruction': 39734,
#  'scheduler': 3646,
#  'add': 37978,
#  'REG1': 11,
#  'r1': 552,
#  'r2': 1052,
#  'REG2': 31,
#  'r3': 77,
#  'r4': 51,
#  'mul': 520,
#  'r5': 246,
#  'instructions': 71872,
#  'defining': 6727,
#  'block': 195032,
#  'aware': 3787,
#  'rule': 13113,
#  'So': 9036,
#  'instance': 33752,
#  'pass': 39535,
#  'vmov.32': 40,
#  'd0': 250,
#  'While': 9460,
#  'd1': 732,
#  'also': 197761,
#  'dangerous': 1100,
#  'register': 39994,
#  'sequence': 50441,
#  'strong': 1281,
#  'write': 45908,
#  'etc': 20498,
#  'looking': 5113,
#  'bug': 13786,
#  'compiler': 72687,
#  'further': 33509,
#  'away': 5863,
#  'mask': 14201,
#  'real': 294317,
#  'enforce': 1919,
#  'non-DAG': 6,
#  'DAG-blocks': 5,
#  'CHECK-LABEL': 46,
#  'containing': 41178,
#  'divided': 6098,
#  'blocks': 56840,
#  'inadvertently': 574,
#  'succeed': 2242,
#  'usually': 32601,
#  'eventually': 1665,
#  'generated': 49904,
#  'flagged': 1251,
#  'causing': 3306,
#  'actually': 21252,
#  'bear': 286,
#  'relationship': 1726,
#  'actual': 17276,
#  'source': 98799,
#  'problem': 39544,
#  'produce': 12247,
#  'better': 12167,
#  'treated': 13711,
#  'identically': 1430,
#  'normal': 26847,
#  'except': 42282,
#  'makes': 27409,
#  'additional': 30896,
#  'assumption': 1931,
#  'matched': 7234,
#  'present': 27215,
#  'intended': 14202,
#  'unique': 13075,
#  'identifiers': 4605,
#  'Conceptually': 178,
#  'presence': 3157,
#  'divides': 1215,
#  'stream': 54992,
#  'separate': 22182,
#  'each': 167184,
#  'processed': 14387,
#  'independently': 2666,
#  'preventing': 952,
#  'struct.C*': 25,
#  'C_ctor_base': 15,
#  'mov': 259,
#  'SAVETHIS': 10,
#  'r0': 282,
#  'bl': 1010,
#  'A_ctor_base': 10,
#  'struct.A*': 15,
#  'struct.B*': 15,
#  'call2': 5,
#  'B_ctor_base': 5,
#  'struct.D*': 10,
#  'D_ctor_base': 10,
#  'ensures': 2763,
#  'three': 68224,
#  'accept': 12108,
#  'corresponding': 82221,
#  'body': 10077,
#  'function': 340365,
#  'even': 55951,
#  'Furthermore': 2278,
#  'fail': 17202,
#  'recover': 1095,
#  'continuing': 600,
#  'allowing': 5135,
#  'failures': 2586,
#  'detected': 10406,
#  'single': 63382,
#  'invocation': 3835,
#  'There': 32792,
#  'requirement': 5922,
#  'correspond': 10307,
#  'syntactic': 536,
#  'language': 22377,
#  'simply': 13840,
#  'uniquely': 1085,
#  'verified': 1619,
#  'definitions': 9196,
#  'Pattern': 734,
#  'Matching': 447,
#  'Syntax': 4537,
#  'All': 42516,
#  'take': 24322,
#  'perfectly': 621,
#  'sufficient': 4770,
#  'things': 10483,
#  'flexible': 2407,
#  'form': 174905,
#  'desired': 25494,
#  'support': 81057,
#  'regular': 16773,
#  'expressions': 12824,
#  'surrounded': 737,
#  'braces': 1441,
#  'yourregex': 5,
#  'Because': 7107,
#  'majority': 912,
#  'has': 262432,
#  'been': 136468,
#  'designed': 7968,
#  'mixing': 987,
#  'xmm': 14,
#  '0-7': 299,
#  'ESP': 287,
#  'enclosed': 2122,
#  'visually': 372,
#  'distinct': 2367,
#  'escape': 6442,
#  'characters': 57190,
#  'within': 47506,
#  'C.': 53277,
#  'rare': 2537,
#  'explicitly': 23566,
#  'ugly': 382,
#  'Variables': 3200,
#  'often': 11020,
#  'again': 12836,
#  'codegen': 22,
#  'allow': 28406,
#  'consistently': 520,
#  'named': 29554,
#  'defined': 117536,
#  'substituted': 1640,
#  'test5': 12,
#  'notw': 5,
#  'REGISTER': 121,
#  'a-z': 449,
#  'andw': 10,
#  'regex': 4280,
#  'captures': 560,
#  'second': 49053,
#  'references': 16614,
#  'always': 53106,
#  'contained': 9954,
#  'pairs': 14682,
#  'their': 54284,
#  'names': 66075,
#  'formed': 8258,
#  'a-zA-Z': 79,
#  'a-zA-Z0-9': 40,
#  'colon': 4562,
#  'follows': 69411,
#  'name': 237906,
#  'times': 30335,
#  'latest': 6411,
#  'were': 52320,
#  'op': 19101,
#  'REG': 52,
#  'Can': 7117,
#  'operands': 2552,
#  'care': 5109,
#  'Expressions': 607,
#  'refers': 5752,
#  'numbers': 47351,
#  'diagnostics': 3118,
#  'introduces': 1336,
#  'certain': 19254,
#  'fragility': 6,
#  'structure': 84293,
#  'absolute': 36663,
#  'updated': 30877,
#  'whenever': 10504,
#  'due': 15612,
#  'addition': 18309,
#  'deletion': 1371,
#  'LINE': 1808,
#  'LINE+': 5,
#  'LINE-': 5,
#  'These': 64581,
#  'expand': 3002,
#  'optional': 36060,
#  'integer': 751475,
#  'way': 40792,
#  'put': 16868,
#  'near': 3833,
#  'relevant': 7481,
#  'include': 87935,
#  'relative': 51961,
#  'test.cpp': 8,
#  'LINE+4': 5,
#  ':6': 25,
#  "'": 2423547,
#  'top': 25398,
#  'level': 59856,
#  'declarator': 58,
#  '^int': 5,
#  '^': 5930,
#  '\\^': 98,
#  'int': 403168,
#  'Maintained': 264,
#  'Team': 2693,
#  '//llvm.org/': 129,
#  'COPYRIGHT': 35738,
#  '2003-2017': 83,
#  'Project': 5339,
#  'llvm-3.9_3.9.1-19ubuntu1_amd64': 29,
#  'check-prefixes': 4,
#  'prefix1': 20,
#  'prefix2': 24,
#  'An': 49529,
#  'alias': 14750,
#  'comma': 5432,
#  'separated': 16981,
#  'list': 177311,
#  'match-full-lines': 4,
#  'require': 19047,
#  'cover': 1728,
#  'entire': 12670,
#  'Leading': 1223,
#  'trailing': 9546,
#  'ignored': 31353,
#  'Note': 139547,
#  'affected': 4463,
#  'Passing': 3410,
#  'equivalent': 35062,
#  'inserting': 1224,
#  'every': 23560,
#  'Newline': 251,
#  'Characters': 792,
#  'character': 239689,
#  'class': 80990,
#  'DW_AT_location': 8,
#  'DW_FORM_sec_offset': 8,
#  'DLOC:0x': 4,
#  '0-9a-f': 55,
#  'intd': 15,
#  'llvm-dwarfdump': 47,
#  '0x00000233': 8,
#  'DW_AT_name': 6,
#  'DW_FORM_strp': 4,
#  '.debug_str': 82,
#  '0x000000c9': 4,
#  'letting': 521,
#  'us': 5053,
#  'set': 354970,
#  'DLOC': 4,
#  'extracted': 3585,
#  'immediately': 17496,
#  'preceding': 3406,
#  'llvm-4.0_4.0.1-10_amd64': 29,
#  '2003-2018': 979,
#  'llvm-5.0_5.0.1-4_amd64': 29,
#  'enable-var-scope': 6,
#  'Enables': 8054,
#  'start': 39726,
#  'considered': 18919,
#  'throughout': 867,
#  'encountered': 11906,
#  'effect': 37582,
#  'local': 47220,
#  'cleared': 3774,
#  'beginning': 13470,
#  'Global': 3177,
#  'easier': 3328,
#  'ensure': 12682,
#  'individual': 10800,
#  'llvm-6.0_6.0-1ubuntu2_amd64': 54,
#  '-D': 8675,
#  'VAR=VALUE': 19,
#  'Sets': 19028,
#  'filecheck': 14,
#  'VAR': 492,
#  'VALUE': 13188,
#  'implements': 6848,
#  'POSIX': 10824,
#  'expression': 28033,
#  'matcher': 265,
#  'supports': 31359,
#  'Extended': 19715,
#  'ERE': 80,
#  'a-zA-Z_': 9,
#  'a-zA-Z0-9_': 35,
#  'forensics-colorize': 15,
#  'show': 19855,
#  'color': 40188,
#  'graphics': 7511,
#  'forensics-colorize_1.1-2_amd64': 3,
#  'filecompare': 21,
#  'size': 184977,
#  'bkmgpe': 3,
#  '-Vh': 12,
#  'FILE1': 131,
#  'FILE2': 131,
#  'colorize': 751,
#  '-h|-V': 10,
#  '-w': 8086,
#  'num': 13288,
#  '-ovd': 3,
#  'FILES': 9675,
#  'compare': 7205,
#  'large': 27293,
#  'filesystem': 20373,
#  'images': 14819,
#  'creating': 11947,
#  'intuitive': 301,
#  'produced': 9915,
#  'provide': 26813,
#  'quick': 2048,
#  'perfect': 571,
#  'sense': 6488,
#  'percentage': 5358,
#  'Comparing': 96,
#  'textual': 1768,
#  'diff': 5380,
#  'big': 4178,
#  'confusion': 1183,
#  ...}

# %%
import collections
sorted_frequency = sorted(frequency.items(), key=lambda kv: kv[1], reverse=True)
sorted_frequency

sorted_frequency_dict = {}

for each in sorted_frequency:
    sorted_frequency_dict[each[0]] = each[1]

sorted_frequency_dict
# Out:
# {',': 14020165,
#  'the': 9696302,
#  '.': 9642163,
#  '(': 6945620,
#  ')': 6935146,
#  'of': 4970406,
#  'is': 4828078,
#  ':': 3941590,
#  '=': 3593068,
#  'to': 3213862,
#  'and': 2701225,
#  'a': 2663866,
#  "'": 2423547,
#  'in': 2032065,
#  'The': 1937719,
#  'for': 1557468,
#  '>': 1460096,
#  'A': 1374498,
#  'be': 1354041,
#  'by': 1342902,
#  'or': 1292196,
#  'dimension': 1281492,
#  'N': 1267868,
#  ';': 1264813,
#  "''": 1119019,
#  'if': 1088237,
#  '--': 1080039,
#  '*': 1074666,
#  '``': 1068686,
#  'are': 1056255,
#  'matrix': 1048430,
#  'array': 998012,
#  '1': 979673,
#  '0': 940677,
#  'that': 938487,
#  'as': 923273,
#  'with': 885448,
#  'not': 874848,
#  '<': 834333,
#  'This': 776749,
#  'an': 776448,
#  'If': 769744,
#  ']': 761051,
#  '[': 760436,
#  'integer': 751475,
#  'on': 696103,
#  'INTEGER': 694150,
#  'this': 663519,
#  '$': 651423,
#  'file': 615594,
#  '-': 596615,
#  'value': 581531,
#  'INFO': 568770,
#  'will': 556368,
#  'it': 516584,
#  'from': 504918,
#  'can': 503962,
#  'number': 487318,
#  '#': 482641,
#  'used': 471096,
#  'which': 425689,
#  'M': 419972,
#  'On': 419156,
#  'int': 403168,
#  'UPLO': 397973,
#  'B': 395127,
#  'i': 389484,
#  'WORK': 386216,
#  'Univ': 377326,
#  'use': 376324,
#  'L': 376194,
#  'Ubuntu': 376153,
#  'Canonical': 375029,
#  'default': 372182,
#  'exit': 368381,
#  'option': 358230,
#  'set': 354970,
#  'triangular': 353401,
#  'LDA': 343331,
#  'function': 340365,
#  'error': 333888,
#  'C': 330485,
#  'only': 325123,
#  'when': 314710,
#  'all': 314067,
#  'you': 309539,
#  'U': 307618,
#  'then': 304523,
#  'may': 298900,
#  'one': 295270,
#  'real': 294317,
#  'at': 293892,
#  'Q': 292281,
#  'upper': 290415,
#  'entry': 285860,
#  'LWORK': 280975,
#  '{': 272397,
#  '}': 271414,
#  '2': 271258,
#  'must': 264937,
#  'subroutine': 264593,
#  'k': 262895,
#  'has': 262432,
#  'first': 256578,
#  'data': 255136,
#  'Manpage': 250206,
#  'Ltd': 249569,
#  'using': 245962,
#  'H': 245936,
#  'double': 240934,
#  '·': 240210,
#  'specified': 239815,
#  'character': 239689,
#  'name': 237906,
#  '3': 236810,
#  'no': 236800,
#  'where': 236135,
#  'code': 233565,
#  'j': 230836,
#  'leading': 230716,
#  'X': 230668,
#  'any': 229501,
#  'const': 226211,
#  '|': 222562,
#  'columns': 221893,
#  'argument': 220224,
#  'precision': 219983,
#  'device': 217088,
#  'D': 214566,
#  'returns': 212270,
#  'lower': 211509,
#  'format': 204294,
#  'output': 203910,
#  'order': 202744,
#  'max': 202213,
#  'SIDE': 201911,
#  'For': 201904,
#  'also': 197761,
#  'Parameters': 197701,
#  '...': 196864,
#  'returned': 196474,
#  'V': 195689,
#  'block': 195032,
#  'define': 194862,
#  'See': 194766,
#  'stored': 193695,
#  'complex': 192901,
#  'values': 192480,
#  'options': 192202,
#  'but': 191918,
#  'have': 191503,
#  'char': 190237,
#  'DOUBLE': 189785,
#  'PRECISION': 189486,
#  'should': 189477,
#  'n': 189238,
#  'AP': 189182,
#  'void': 188628,
#  'type': 188037,
#  'size': 184977,
#  'string': 184581,
#  'K': 183509,
#  'memory': 182418,
#  'part': 182236,
#  "'s": 180267,
#  'REAL': 179382,
#  'list': 177311,
#  'contains': 175232,
#  'form': 174905,
#  'Z': 174118,
#  'elements': 171993,
#  'diagonal': 169884,
#  'files': 169451,
#  'than': 168543,
#  'return': 168318,
#  'same': 167570,
#  'each': 167184,
#  '@': 165485,
#  'command': 164481,
#  'version': 162328,
#  'object': 161881,
#  'A.': 160318,
#  'It': 157778,
#  'input': 156454,
#  'Y': 153611,
#  'more': 151030,
#  'new': 150721,
#  'I': 150028,
#  'does': 149582,
#  'given': 149236,
#  'main': 148548,
#  'LDB': 148035,
#  'T': 146290,
#  'bugs': 146288,
#  'information': 146049,
#  '+': 145903,
#  'Berkeley': 144774,
#  'eigenvalues': 144428,
#  'was': 143940,
#  'California': 143258,
#  'R': 142962,
#  'rows': 142146,
#  'content': 141778,
#  'other': 141427,
#  'registered': 140171,
#  'Note': 139547,
#  'NAME': 139470,
#  'vector': 139296,
#  'system': 138742,
#  'call': 138634,
#  'line': 138394,
#  'menu': 137744,
#  'Author': 137383,
#  'been': 136468,
#  '©': 134038,
#  'CHARACTER*1': 133753,
#  'computed': 133302,
#  'its': 131416,
#  'into': 131380,
#  '%': 130070,
#  'x': 129512,
#  'Date': 129259,
#  'see': 127534,
#  'Purpose': 127528,
#  'Close': 126547,
#  'functions': 126155,
#  'RFP': 126092,
#  'TRANS': 126030,
#  'Menu': 125898,
#  'P': 125810,
#  'Ltd.': 125711,
#  'following': 125579,
#  'do': 125482,
#  'Jump': 125355,
#  'Provided': 125287,
#  'Repository': 125174,
#  'Launchpad': 125128,
#  'trademarks': 124973,
#  '2019': 124945,
#  'Powered': 124933,
#  'Colorado': 124909,
#  'Denver': 124886,
#  'Tennessee': 124632,
#  'NAG': 124073,
#  'time': 123132,
#  'so': 123085,
#  'mode': 122925,
#  'program': 121489,
#  'column': 120436,
#  'user': 120159,
#  'current': 118761,
#  'factorization': 118227,
#  'CUDA': 118165,
#  'contain': 118114,
#  'example': 118032,
#  'right': 117918,
#  'defined': 117536,
#  'TAU': 117278,
#  'Returns': 116597,
#  'In': 114664,
#  'E': 114374,
#  'two': 114160,
#  'pointer': 112531,
#  'elementary': 112333,
#  'such': 111201,
#  'i-th': 110868,
#  'element': 109926,
#  'DESCRIPTION': 109222,
#  'S': 108847,
#  'width': 108174,
#  'message': 107895,
#  'zero': 107878,
#  '2016': 106726,
#  'referenced': 106104,
#  'unsigned': 106030,
#  'address': 103982,
#  'NRHS': 103586,
#  'directory': 102904,
#  'successful': 102882,
#  'handle': 102197,
#  'IPIV': 101998,
#  'available': 101992,
#  'key': 101479,
#  'When': 101386,
#  'SYNOPSIS': 101155,
#  'struct': 101041,
#  'some': 99256,
#  'parameter': 98943,
#  'source': 98799,
#  'singular': 98043,
#  '-i': 97593,
#  'December': 97554,
#  'reflectors': 96171,
#  'routine': 96136,
#  'above': 95702,
#  'after': 95445,
#  'had': 93554,
#  'case': 93509,
#  'COMPLEX': 92725,
#  'your': 92345,
#  'variable': 91704,
#  'standard': 91625,
#  '5': 91393,
#  'called': 91125,
#  'COMPLEX*16': 90873,
#  'method': 90818,
#  'these': 90664,
#  'illegal': 90343,
#  'AB': 90240,
#  'computes': 90216,
#  'complex*16': 90043,
#  'Details': 89856,
#  'enum': 89850,
#  's': 88803,
#  '4': 88527,
#  'eigenvectors': 88415,
#  'include': 87935,
#  'last': 86705,
#  'server': 86599,
#  'details': 86587,
#  'between': 86400,
#  'before': 86286,
#  'either': 85759,
#  'structure': 84293,
#  'factor': 84238,
#  'specifies': 84086,
#  'left': 83830,
#  'process': 83426,
#  '&': 82745,
#  'height': 82691,
#  'To': 82399,
#  'corresponding': 82221,
#  'library': 82210,
#  'solution': 81984,
#  'supported': 81959,
#  'triangle': 81831,
#  'about': 81342,
#  'bytes': 81220,
#  'support': 81057,
#  'class': 80990,
#  'Specifies': 80952,
#  'NULL': 80850,
#  'surface': 79998,
#  'Further': 79345,
#  'enabled': 79279,
#  'IWORK': 78927,
#  '22': 78721,
#  'product': 78342,
#  'otherwise': 78335,
#  'row': 78140,
#  'symmetric': 77316,
#  'they': 77227,
#  'norm': 77030,
#  'below': 76991,
#  '-1': 76986,
#  'whether': 76974,
#  'passed': 76923,
#  'my': 76450,
#  'indicates': 76296,
#  'without': 75839,
#  'http': 75742,
#  'SEE': 75692,
#  '/': 75677,
#  'ALSO': 75627,
#  'condition': 75596,
#  'matrices': 75302,
#  'there': 75024,
#  '11': 74898,
#  'You': 74731,
#  'W': 74710,
#  '10': 74516,
#  "n't": 74054,
#  'channel': 73982,
#  'v': 73878,
#  'operation': 73372,
#  'long': 73116,
#  'optimal': 73024,
#  'both': 72893,
#  'read': 72722,
#  'compiler': 72687,
#  'LDC': 72665,
#  '?': 72597,
#  'algorithm': 72494,
#  'configuration': 72475,
#  'widget': 71952,
#  'instructions': 71872,
#  'specify': 71786,
#  'TRANSR': 71778,
#  'instead': 71211,
#  'like': 70482,
#  'scalar': 69986,
#  'flag': 69876,
#  'result': 69739,
#  'follows': 69411,
#  '00': 68908,
#  'typedef': 68902,
#  'target': 68877,
#  'parameters': 68662,
#  'up': 68507,
#  'Set': 68394,
#  'three': 68224,
#  'orthogonal': 68212,
#  'page': 67838,
#  'length': 67503,
#  'path': 67409,
#  'transpose': 66900,
#  '8': 66874,
#  'section': 66706,
#  'arguments': 66251,
#  'uses': 66178,
#  'names': 66075,
#  'attribute': 65904,
#  'found': 65655,
#  '33': 65412,
#  'image': 65321,
#  'Use': 64986,
#  'buffer': 64979,
#  '44': 64891,
#  'text': 64753,
#  'These': 64581,
#  'module': 64101,
#  'least': 63944,
#  'single': 63382,
#  'index': 63315,
#  'run': 63231,
#  'maximum': 62696,
#  'vectors': 62575,
#  'host': 62371,
#  'B.': 62343,
#  'driver': 62115,
#  'bits': 62053,
#  'assumed': 61661,
#  'size_t': 61377,
#  'Default': 60963,
#  'context': 60956,
#  'LDT': 60594,
#  'm': 60583,
#  'space': 60320,
#  'unitary': 60291,
#  'calling': 60284,
#  'packed': 60176,
#  'level': 59856,
#  'apply': 59430,
#  'being': 59229,
#  'Maximum': 59006,
#  'query': 58526,
#  'VL': 58454,
#  'point': 58315,
#  '!': 58246,
#  'consists': 58195,
#  'different': 57775,
#  'LDAB': 57535,
#  'possible': 57527,
#  'entries': 57508,
#  'reference': 57431,
#  'written': 57345,
#  'characters': 57190,
#  'GCC': 56896,
#  'blocks': 56840,
#  'true': 56736,
#  'original': 56638,
#  'field': 56489,
#  'sets': 56357,
#  'out': 56212,
#  'full': 56155,
#  'work': 56111,
#  'help': 56048,
#  'LDZ': 56004,
#  'even': 55951,
#  'need': 55796,
#  'range': 55731,
#  'get': 55419,
#  'just': 55284,
#  'them': 55281,
#  'bound': 55211,
#  '`': 55019,
#  'stream': 54992,
#  'RWORK': 54975,
#  'calls': 54945,
#  'access': 54793,
#  'required': 54667,
#  'tridiagonal': 54338,
#  'their': 54284,
#  'via': 53982,
#  'and/or': 53979,
#  'through': 53828,
#  'types': 53764,
#  '12': 53630,
#  'shared': 53605,
#  'LDQ': 53518,
#  'y': 53467,
#  'flags': 53399,
#  'C.': 53277,
#  'always': 53106,
#  'window': 52966,
#  'under': 52900,
#  'lda': 52789,
#  'general': 52765,
#  'interface': 52395,
#  'were': 52320,
#  'associated': 52250,
#  'application': 52030,
#  'relative': 51961,
#  'multiple': 51852,
#  'provided': 51678,
#  'would': 50977,
#  'unit': 50835,
#  'M-by-N': 50828,
#  'sequence': 50441,
#  'copy': 50419,
#  'because': 50349,
#  '32': 50192,
#  '=i': 50050,
#  'request': 50030,
#  'reflector': 50023,
#  'eigenvalue': 50013,
#  'DIAG': 49912,
#  'generated': 49904,
#  'API': 49655,
#  'An': 49529,
#  'c': 49442,
#  'port': 49383,
#  'selected': 49351,
#  'related': 49333,
#  'most': 49306,
#  'second': 49053,
#  'kernel': 48973,
#  'table': 48958,
#  'b': 48952,
#  'change': 48778,
#  'control': 48628,
#  'end': 48590,
#  'warning': 48575,
#  'created': 48235,
#  'LDV': 48192,
#  'create': 47934,
#  '7': 47867,
#  'reciprocal': 47766,
#  'Schur': 47713,
#  'make': 47646,
#  'U/V': 47553,
#  'No': 47538,
#  'within': 47506,
#  'numbers': 47351,
#  '*/': 47331,
#  'X11': 47269,
#  'local': 47220,
#  'texture': 47212,
#  'overwritten': 47150,
#  'useful': 47104,
#  '20': 46958,
#  'package': 46868,
#  'Upper': 46712,
#  'errors': 46677,
#  'Lower': 46572,
#  'Perl': 46554,
#  'LDX': 46478,
#  'AUTHOR': 46377,
#  'those': 45993,
#  'write': 45908,
#  'N-by-N': 45842,
#  'j-th': 45826,
#  'NB': 45747,
#  'we': 45685,
#  'callback': 45667,
#  'THETA': 45646,
#  'IHI': 45634,
#  'print': 45600,
#  '2008-02-05T18:30:30': 45398,
#  '1995-12-22T09:05:02': 45397,
#  '-0010-09-15T04:44:23': 45397,
#  'ILO': 45348,
#  'database': 45339,
#  'GNU': 45329,
#  'MAX': 45297,
#  'compute': 45180,
#  'state': 45142,
#  'variables': 45062,
#  'linker': 44675,
#  'operations': 44671,
#  'objects': 44573,
#  'automatically': 44500,
#  '/*': 44429,
#  'environment': 44325,
#  'header': 44218,
#  'largest': 44123,
#  'factors': 43963,
#  'globus_result_t': 43842,
#  'workspace': 43637,
#  'location': 43545,
#  'RCOND': 43370,
#  'specific': 43283,
#  'count': 43120,
#  'means': 43031,
#  '14': 42960,
#  'previous': 42886,
#  'All': 42516,
#  'messages': 42482,
#  '30': 42408,
#  'global': 42375,
#  'check': 42299,
#  'except': 42282,
#  'match': 42150,
#  'valid': 42145,
#  'less': 42130,
#  'allows': 42129,
#  '6': 42106,
#  '/2': 42085,
#  'side': 42033,
#  'client': 41888,
#  'event': 41863,
#  'Do': 41785,
#  'currently': 41575,
#  'SELECT': 41439,
#  'how': 41315,
#  'want': 41237,
#  'commands': 41230,
#  'containing': 41178,
#  'd': 41149,
#  'what': 41063,
#  'free': 40987,
#  'generate': 40914,
#  'resource': 40878,
#  'i.e.': 40864,
#  'bidiagonal': 40838,
#  'defines': 40831,
#  'band': 40793,
#  'way': 40792,
#  'stack': 40742,
#  'filename': 40712,
#  'Each': 40479,
#  'N.': 40382,
#  'done': 40360,
#  'linear': 40338,
#  'cases': 40310,
#  'performance': 40201,
#  'color': 40188,
#  'display': 40026,
#  'register': 39994,
#  'based': 39836,
#  'instruction': 39734,
#  'start': 39726,
#  'KD': 39708,
#  'macro': 39689,
#  'issued': 39658,
#  'OPTIONS': 39614,
#  'problem': 39544,
#  'pass': 39535,
#  'JOB': 39503,
#  'Generate': 39341,
#  'manual': 39197,
#  'devices': 39160,
#  '23': 39056,
#  'behavior': 38867,
#  'could': 38778,
#  'during': 38778,
#  '13': 38585,
#  'while': 38513,
#  'documentation': 38437,
#  'next': 38420,
#  'per': 38382,
#  'attributes': 38378,
#  '\\': 38215,
#  '24': 38201,
#  'add': 37978,
#  'T.': 37953,
#  'VU': 37940,
#  'positive': 37836,
#  'G': 37733,
#  'storage': 37603,
#  'effect': 37582,
#  'software': 37538,
#  'hand': 37530,
#  'described': 37487,
#  'group': 37480,
#  'whose': 37439,
#  'plugin': 37328,
#  'pair': 37291,
#  'symbol': 37289,
#  'systems': 37281,
#  'description': 37110,
#  'University': 37107,
#  'respectively': 37103,
#  'Device': 36749,
#  'status': 36724,
#  'setting': 36712,
#  'absolute': 36663,
#  '21': 36600,
#  'already': 36567,
#  'link': 36394,
#  'contents': 36349,
#  'equal': 36223,
#  'binary': 36150,
#  'bit': 36126,
#  '40': 36116,
#  'NORM': 36107,
#  'optional': 36060,
#  'methods': 36028,
#  'trapezoidal': 35949,
#  'supplied': 35903,
#  '31': 35874,
#  'since': 35837,
#  '2-by-2': 35822,
#  'connection': 35753,
#  'Copyright': 35742,
#  'COPYRIGHT': 35738,
#  'Q.': 35707,
#  'floating-point': 35692,
#  'script': 35616,
#  'X.': 35610,
#  'USA': 35584,
#  'INCX': 35478,
#  'By': 35438,
#  'ALPHA': 35411,
#  'off': 35351,
#  'N+1': 35347,
#  'Hermitian': 35292,
#  'boolean': 35170,
#  'equivalent': 35062,
#  '15': 35055,
#  'itself': 35054,
#  'PHI': 35034,
#  '42': 34875,
#  'small': 34850,
#  '34': 34705,
#  "'T": 34668,
#  'many': 34630,
#  'lines': 34607,
#  'node': 34555,
#  'Options': 34530,
#  'usage': 34489,
#  'base': 34480,
#  'internal': 34375,
#  'Enumerator': 34362,
#  'inverse': 34261,
#  'C++': 34121,
#  'search': 34014,
#  'added': 34000,
#  'needed': 33891,
#  'complete': 33811,
#  'instance': 33752,
#  '41': 33734,
#  '43': 33695,
#  'VR': 33672,
#  '55': 33631,
#  'unless': 33604,
#  'eigenvector': 33595,
#  'Specify': 33544,
#  'further': 33509,
#  'running': 33465,
#  'LIWORK': 33391,
#  'estimate': 33364,
#  'cache': 33303,
#  'provides': 33257,
#  'F': 33203,
#  '01': 33142,
#  'very': 33034,
#  'Q1': 33022,
#  'e.g': 32799,
#  'There': 32792,
#  '03': 32718,
#  'M-P': 32638,
#  'X21': 32634,
#  'ID': 32624,
#  'usually': 32601,
#  'test': 32534,
#  'determined': 32409,
#  'over': 32333,
#  '04': 32246,
#  'calculates': 32193,
#  'N-1': 32165,
#  'might': 32104,
#  'invalid': 31973,
#  'terms': 31963,
#  'hash': 31960,
#  '02': 31842,
#  'greater': 31827,
#  'BETA': 31688,
#  'License': 31678,
#  'log': 31674,
#  'extension': 31623,
#  'failed': 31616,
#  'another': 31588,
#  'i.e': 31497,
#  'root': 31456,
#  '50': 31437,
#  'made': 31425,
#  'supports': 31359,
#  'ignored': 31353,
#  'XERBLA': 31340,
#  'modify': 31204,
#  'k-1': 31195,
#  'w': 31069,
#  'JOBZ': 31069,
#  'v1': 30949,
#  'represented': 30940,
#  'TYPE': 30901,
#  'additional': 30896,
#  'thread': 30886,
#  'updated': 30877,
#  'We': 30825,
#  'Enable': 30793,
#  'rotations': 30665,
#  'store': 30573,
#  'ordering': 30544,
#  'results': 30510,
#  'times': 30335,
#  'machine': 30324,
#  'filter': 30257,
#  'tree': 30179,
#  'allowed': 30156,
#  'equations': 30154,
#  'j-1': 30083,
#  'loop': 29996,
#  'initialized': 29973,
#  'i+1': 29943,
#  'tag': 29932,
#  'sub': 29828,
#  'Linux': 29782,
#  'well': 29753,
#  'particular': 29750,
#  'static': 29746,
#  'changes': 29697,
#  'empty': 29682,
#  'limit': 29637,
#  'implementation': 29616,
#  'URL': 29580,
#  'named': 29554,
#  'interleaved': 29456,
#  'bounds': 29435,
#  'feature': 29416,
#  'including': 29399,
#  'runtime': 29369,
#  'none': 29258,
#  'byte': 29237,
#  'surfaces': 29232,
#  'screen': 29141,
#  'Get': 29101,
#  'position': 29044,
#  'existing': 29032,
#  'v2': 28952,
#  'special': 28882,
#  'Not': 28717,
#  'programs': 28662,
#  'arrays': 28652,
#  'scaling': 28622,
#  '__extern': 28592,
#  'M-Q': 28490,
#  'rectangular': 28431,
#  'allow': 28406,
#  'generates': 28368,
#  'representation': 28361,
#  'June': 28069,
#  'integers': 28046,
#  'u': 28036,
#  'expression': 28033,
#  'debug': 27990,
#  'allocated': 27974,
#  'info': 27963,
#  'Hessenberg': 27897,
#  'later': 27787,
#  '32-bit': 27767,
#  'performed': 27763,
#  'fields': 27755,
#  'similar': 27727,
#  'seconds': 27704,
#  'min': 27653,
#  'directly': 27606,
#  'place': 27595,
#  'h': 27484,
#  '0x01': 27480,
#  'CPU': 27431,
#  'makes': 27409,
#  'offset': 27401,
#  'reduced': 27376,
#  'find': 27312,
#  'large': 27293,
#  'give': 27220,
#  'present': 27215,
#  'HOWMNY': 27188,
#  'versions': 27172,
#  'too': 27120,
#  'load': 27118,
#  'directories': 27087,
#  '1/2': 27079,
#  'points': 27064,
#  'LDU': 27045,
#  '2D': 27022,
#  'modified': 27003,
#  'overflow': 26990,
#  'keys': 26985,
#  'template': 26964,
#  'Compute': 26863,
#  'normal': 26847,
#  'provide': 26813,
#  'However': 26812,
#  'std': 26792,
#  'cause': 26781,
#  'interval': 26769,
#  'accessed': 26666,
#  'debugging': 26641,
#  'attr': 26563,
#  'action': 26532,
#  'denotes': 26495,
#  'applies': 26463,
#  'enable': 26453,
#  'backward': 26419,
#  'RANGE': 26373,
#  'id': 26310,
#  'QR': 26307,
#  'smallest': 26305,
#  'changed': 26299,
#  'Return': 26255,
#  'report': 26247,
#  '’': 26191,
#  'Only': 26133,
#  'k+1': 26093,
#  'transformation': 26089,
#  'subdiagonal': 26057,
#  'libraries': 26032,
#  'applied': 25973,
#  'tau': 25927,
#  'larger': 25878,
#  'exactly': 25876,
#  'identifier': 25718,
#  '=j': 25717,
#  'generalized': 25703,
#  'update': 25696,
#  'starting': 25687,
#  'map': 25675,
#  'threshold': 25638,
#  'socket': 25636,
#  'Display': 25634,
#  'until': 25629,
#  'remote': 25532,
#  'here': 25504,
#  'desired': 25494,
#  'Print': 25451,
#  'top': 25398,
#  'STOREV': 25354,
#  '51': 25351,
#  'represent': 25341,
#  'Example': 25334,
#  'signed': 25334,
#  '1-norm': 25321,
#  'success': 25290,
#  'execution': 25263,
#  'FILE': 25249,
#  'deprecated': 25216,
#  'strictly': 25112,
#  'inv': 25102,
#  'included': 25072,
#  'Contributors': 25011,
#  'N*': 24957,
#  'scale': 24948,
#  'Otherwise': 24933,
#  'rather': 24864,
#  'compiled': 24830,
#  'false': 24828,
#  'GPU': 24795,
#  'strings': 24699,
#  'switch': 24674,
#  'takes': 24641,
#  'COMPZ': 24619,
#  'determine': 24604,
#  'constant': 24525,
#  'protocol': 24426,
#  'transfer': 24405,
#  'registers': 24400,
#  'float': 24355,
#  'take': 24322,
#  'requested': 24149,
#  'ldb': 24124,
#  'still': 24051,
#  'encoding': 24021,
#  'send': 24016,
#  'total': 23996,
#  'frame': 23937,
#  'prefix': 23930,
#  'overwrites': 23929,
#  'back': 23919,
#  'defaults': 23910,
#  'negative': 23883,
#  'once': 23825,
#  'document': 23803,
#  'open': 23799,
#  'symbols': 23755,
#  'Warn': 23734,
#  'v3': 23711,
#  'abs': 23704,
#  'network': 23688,
#  'job': 23655,
#  'https': 23637,
#  'Bio': 23618,
#  'simple': 23611,
#  'explicitly': 23566,
#  'every': 23560,
#  'performs': 23497,
#  'requires': 23414,
#  '52': 23373,
#  ...}

# %%
s = [sorted_frequency_dict[each]  for each in sorted_frequency_dict]

# %%
len(s)
# Out:
# 1530249

# %%
# Take only the words from index lim1 to index lim2 in the sorted frequency dict as the zipf words

lim1 = 1000
lim2 = 30000
print(s[lim1])
print(s[lim2])
plt.plot(range(len(s))[lim1:lim2], s[lim1:lim2])
plt.show()
# Out:
# 23372
# 196

# %%
zip_list =  list(sorted_frequency_dict.items())[lim1:lim2]
zip_list
# Out:
# [('minimum', 23372),
#  ('common', 23361),
#  ('With', 23315),
#  ('Cholesky', 23295),
#  ('optimization', 23284),
#  ('service', 23216),
#  ('box', 23163),
#  ('Q**H', 23038),
#  ('password', 23037),
#  ('extensions', 22984),
#  ('distribution', 22967),
#  ('25', 22915),
#  ('signal', 22870),
#  ('LDX11', 22792),
#  ('syntax', 22783),
#  ('virtual', 22779),
#  ('declared', 22745),
#  ('final', 22708),
#  ('Format', 22663),
#  ('active', 22627),
#  ('square', 22562),
#  ('copies', 22521),
#  ('estimates', 22510),
#  ('One', 22458),
#  ('targets', 22457),
#  ('initial', 22456),
#  ('certificate', 22444),
#  ('logical', 22438),
#  ('routines', 22399),
#  ('language', 22377),
#  ('model', 22313),
#  ('head', 22279),
#  ('LDX21', 22274),
#  ('successfully', 22253),
#  ('removed', 22245),
#  ('addresses', 22238),
#  ('separate', 22182),
#  ('queue', 22162),
#  ('pattern', 22130),
#  ('Any', 22120),
#  ('”', 22086),
#  ('BERR', 22082),
#  ('-h', 22059),
#  ('U1', 22055),
#  ('sections', 22039),
#  ('longer', 22023),
#  ('U2', 22018),
#  ('XML', 21997),
#  ('destination', 21990),
#  ('JOBV', 21978),
#  ('shell', 21944),
#  ('ICOMPQ', 21926),
#  ('hardware', 21918),
#  ('“', 21914),
#  ('-s', 21872),
#  ('permutation', 21864),
#  ('compilation', 21856),
#  ('now', 21827),
#  ('Science', 21820),
#  ('Q**T', 21682),
#  ('LDH', 21670),
#  ('causes', 21574),
#  ('Function', 21459),
#  ('Documentation', 21445),
#  ('perform', 21444),
#  ('p', 21383),
#  ('record', 21382),
#  ('floating', 21363),
#  ('normally', 21362),
#  ('threads', 21360),
#  ("R'", 21339),
#  ('MM', 21336),
#  ('converge', 21322),
#  ('B11', 21301),
#  ('actually', 21252),
#  ('j+1', 21243),
#  ('FERR', 21224),
#  ('matching', 21206),
#  ('trapezoid', 21193),
#  ('occur', 21143),
#  ('TOL', 21100),
#  ('obtained', 21094),
#  ('appropriate', 21093),
#  ('0x02', 21064),
#  ('implemented', 21028),
#  ('necessary', 21021),
#  ('foo', 20993),
#  ('select', 20989),
#  ('equation', 20988),
#  ('disabled', 20930),
#  ('executed', 20841),
#  ('rotation', 20835),
#  ('LDVL', 20832),
#  ('LDVR', 20832),
#  ('completed', 20820),
#  ('-o', 20813),
#  ('-c', 20767),
#  ('J', 20767),
#  ('disable', 20714),
#  ('member', 20710),
#  ('DIRECT', 20700),
#  ('configured', 20695),
#  ('failure', 20683),
#  ('Software', 20667),
#  ('Also', 20653),
#  ('codes', 20645),
#  ('else', 20605),
#  ('close', 20570),
#  ('obtain', 20537),
#  ('tool', 20520),
#  ('etc', 20498),
#  ('-v', 20490),
#  ('architecture', 20431),
#  ('filesystem', 20373),
#  ('DIF', 20313),
#  ('around', 20248),
#  ('2008', 20185),
#  ('optionally', 20172),
#  ('35', 20128),
#  ('region', 20099),
#  ('domain', 20086),
#  ('NOT', 20056),
#  ('ENGINE', 20056),
#  ('formats', 20024),
#  ('BUGS', 20002),
#  ('taken', 19998),
#  ('various', 19975),
#  ('modules', 19897),
#  ('typename', 19885),
#  ('uint32_t', 19869),
#  ('show', 19855),
#  ('As', 19848),
#  ('occurred', 19845),
#  ('avoid', 19814),
#  ('against', 19762),
#  ('Range', 19758),
#  ('Extended', 19715),
#  ('non-zero', 19709),
#  ('replaced', 19700),
#  ('WANTZ', 19675),
#  ('len', 19649),
#  ('Please', 19618),
#  ('shall', 19590),
#  ('UTC', 19582),
#  ('allocation', 19550),
#  ('much', 19533),
#  ('-d', 19530),
#  ('never', 19492),
#  ('M.', 19462),
#  ('64', 19454),
#  ('RETURN', 19414),
#  ('external', 19410),
#  ('16', 19388),
#  ('short', 19365),
#  ('verbose', 19364),
#  ('depth', 19364),
#  ('processing', 19363),
#  ('conjugate', 19357),
#  ('null', 19340),
#  ('url', 19313),
#  ('Version', 19268),
#  ('certain', 19254),
#  ('handler', 19234),
#  ('users', 19217),
#  ('indicate', 19207),
#  ('applications', 19149),
#  ('Level', 19137),
#  ('matches', 19108),
#  ('op', 19101),
#  ('archive', 19082),
#  ('word', 19069),
#  ('known', 19050),
#  ('require', 19047),
#  ('Used', 19034),
#  ('-f', 19029),
#  ('Sets', 19028),
#  ('appear', 19025),
#  ('45', 19021),
#  ('HTML', 19001),
#  ('diag', 18966),
#  ('listed', 18962),
#  ('components', 18920),
#  ('considered', 18919),
#  ('extra', 18907),
#  ('works', 18899),
#  ('therefore', 18896),
#  ('f', 18871),
#  ('Data', 18866),
#  ('terminal', 18839),
#  ('exist', 18833),
#  ('sent', 18779),
#  ('move', 18736),
#  ('channels', 18720),
#  ('undefined', 18709),
#  ('Computer', 18706),
#  ('OpenSSL', 18685),
#  ('warnings', 18675),
#  ('own', 18671),
#  ('uint8_t', 18661),
#  ('53', 18637),
#  ('decomposition', 18584),
#  ('gets', 18523),
#  ('unblocked', 18519),
#  ('dynamic', 18469),
#  ('Some', 18463),
#  ('conversion', 18458),
#  ('installed', 18457),
#  ('item', 18434),
#  ('did', 18422),
#  ('attempt', 18417),
#  ('9', 18394),
#  ('together', 18389),
#  ('executable', 18372),
#  ('Let', 18328),
#  ('VECT', 18327),
#  ('session', 18312),
#  ('addition', 18309),
#  ('IU', 18303),
#  ('IL', 18300),
#  ('checks', 18294),
#  ('config', 18278),
#  ('events', 18269),
#  ('Transpose', 18251),
#  ('Debian', 18219),
#  ('restart', 18215),
#  ('higher', 18194),
#  ('exact', 18153),
#  ('ABI', 18149),
#  ('ISO', 18112),
#  ('represents', 18087),
#  ('suitable', 18066),
#  ('1-by-1', 18065),
#  ('printf', 18054),
#  ('project', 18036),
#  ('cluster', 18032),
#  ('release', 18030),
#  ('fails', 18029),
#  ('generation', 18020),
#  ('54', 18013),
#  ('area', 17998),
#  ('inline', 17994),
#  ('perl', 17984),
#  ('holds', 17941),
#  ('macros', 17873),
#  ('LETTER', 17857),
#  ('-p', 17855),
#  ('component', 17798),
#  ('V.', 17797),
#  ('needs', 17794),
#  ('processes', 17794),
#  ('arg', 17780),
#  ('alignment', 17743),
#  ('interchanged', 17742),
#  ('magnitude', 17735),
#  ('invoked', 17728),
#  ('COMPQ', 17722),
#  ('features', 17715),
#  ('componentwise', 17708),
#  ('several', 17705),
#  ('smaller', 17702),
#  ('Jacobi', 17692),
#  ('nvmlReturn_t', 17682),
#  ('parts', 17666),
#  ('They', 17654),
#  ('immediately', 17496),
#  ('resources', 17472),
#  ('DECLDIR', 17468),
#  ('LRWORK', 17447),
#  ('pages', 17393),
#  ('scaled', 17390),
#  ('build', 17387),
#  ('processor', 17322),
#  ('actual', 17276),
#  ('requests', 17268),
#  ('odd', 17239),
#  ('_', 17231),
#  ('2017', 17205),
#  ('fail', 17202),
#  ('infinity', 17178),
#  ('AND', 17166),
#  ('compatibility', 17164),
#  ('indices', 17160),
#  ('IP', 17140),
#  ('asynchronous', 17139),
#  ('sum', 17104),
#  ('creates', 17095),
#  ('displayed', 17092),
#  ('SQRE', 17084),
#  ('working', 17062),
#  ('Q2', 17047),
#  ('pointers', 17041),
#  ('interchanges', 16994),
#  ('src', 16992),
#  ('reduces', 16989),
#  ('separated', 16981),
#  ('previously', 16949),
#  ('undef', 16947),
#  ('date', 16939),
#  ('1,2', 16938),
#  ('depends', 16914),
#  ('accepts', 16910),
#  ('specifying', 16902),
#  ('assembler', 16892),
#  ('consider', 16875),
#  ('put', 16868),
#  ('rules', 16864),
#  ('enables', 16864),
#  ('Deprecated', 16851),
#  ('AMAX', 16846),
#  ('occurs', 16845),
#  ('ANORM', 16826),
#  ('bool', 16789),
#  ('regular', 16773),
#  ('forward', 16773),
#  ('e', 16766),
#  ('sides', 16760),
#  ('branch', 16760),
#  ('P2', 16749),
#  ('alpha', 16728),
#  ('nvmlDevice_t', 16717),
#  ('Type', 16679),
#  ('exception', 16671),
#  ('exists', 16668),
#  ('let', 16646),
#  ('Tcl', 16634),
#  ('CNORM', 16628),
#  ('0x00', 16623),
#  ('references', 16614),
#  ('layered', 16611),
#  ('Free', 16563),
#  ('Public', 16542),
#  ('LDAF', 16530),
#  ('indicating', 16497),
#  ('plane', 16495),
#  ('scheduling', 16493),
#  ('n-1', 16479),
#  ('bottom', 16449),
#  ('response', 16445),
#  ('cursor', 16444),
#  ('definite', 16442),
#  ('Show', 16393),
#  ('INCY', 16393),
#  ('05', 16375),
#  ('Generated', 16333),
#  ('AF', 16330),
#  ('remove', 16306),
#  ('compressed', 16299),
#  ('try', 16296),
#  ('timeout', 16288),
#  ('font', 16274),
#  ('n1', 16264),
#  ('settings', 16240),
#  ('P1', 16236),
#  ('Unchanged', 16234),
#  ('old', 16233),
#  ('bus', 16228),
#  ('LICENSE', 16180),
#  ('3D', 16172),
#  ('pointed', 16154),
#  ('CUresult', 16140),
#  ('General', 16098),
#  ('four', 16071),
#  ('continue', 16059),
#  ('future', 16058),
#  ('V1T', 16058),
#  ('64-bit', 16056),
#  ('along', 16039),
#  ('policy', 16018),
#  ('preprocessor', 16003),
#  ('machines', 15991),
#  ('Name', 15955),
#  ('16-bit', 15947),
#  ('printed', 15913),
#  ('nodes', 15904),
#  ('amount', 15889),
#  ('SCREEN*', 15881),
#  ('SEP', 15857),
#  ('VT', 15832),
#  ('Description', 15814),
#  ('LAPACK', 15802),
#  ('fully', 15766),
#  ('packet', 15743),
#  ('modes', 15741),
#  ('columnwise', 15700),
#  ('disk', 15631),
#  ('orthonormal', 15628),
#  ('step', 15615),
#  ('due', 15612),
#  ('accuracy', 15610),
#  ('loaded', 15607),
#  ('estimated', 15605),
#  ('descriptor', 15596),
#  ('pivoting', 15581),
#  ('**', 15575),
#  ('procedure', 15562),
#  ('BLAS', 15536),
#  ('File', 15502),
#  ('connections', 15500),
#  ('locale', 15493),
#  ('definition', 15465),
#  ('down', 15451),
#  ('Z.', 15420),
#  ('style', 15389),
#  ('caller', 15386),
#  ('Since', 15366),
#  ('compile', 15363),
#  ('execute', 15304),
#  ('random', 15302),
#  ('distributed', 15279),
#  ('No-op', 15253),
#  ('reduce', 15246),
#  ('volume', 15242),
#  ('0x04', 15240),
#  ('comments', 15231),
#  ('redistribute', 15225),
#  ('convert', 15223),
#  ('decimal', 15220),
#  ('includes', 15210),
#  ('receive', 15197),
#  ('authentication', 15189),
#  ('yet', 15188),
#  ('writing', 15184),
#  ('command-line', 15159),
#  ('followed', 15109),
#  ('O', 15105),
#  ('-l', 15102),
#  ('look', 15086),
#  ('delete', 15076),
#  ('Add', 15055),
#  ('H.', 15048),
#  ('//', 15023),
#  ('Windows', 15019),
#  ('specification', 15011),
#  ('chtype', 15006),
#  ('==', 15002),
#  ('expected', 14952),
#  ('power', 14948),
#  ('Net', 14935),
#  ('label', 14874),
#  ('resulting', 14860),
#  ('structures', 14857),
#  ('forms', 14829),
#  ('profile', 14822),
#  ('images', 14819),
#  ('note', 14812),
#  ('levels', 14798),
#  ('examples', 14789),
#  ('-m', 14770),
#  ('alias', 14750),
#  ('able', 14736),
#  ('Here', 14723),
#  ('correct', 14706),
#  ('100', 14699),
#  ('kind', 14684),
#  ('pairs', 14682),
#  ('submatrix', 14673),
#  ('words', 14668),
#  ('private', 14629),
#  ('=n', 14603),
#  ('squares', 14599),
#  ('Number', 14539),
#  ('Create', 14530),
#  ('superdiagonal', 14474),
#  ('_CharT', 14469),
#  ('EPS', 14467),
#  ('Error', 14444),
#  ('lists', 14442),
#  ('hold', 14416),
#  ('override', 14410),
#  ('recommended', 14407),
#  ('processed', 14387),
#  ('statement', 14378),
#  ('basic', 14372),
#  ('background', 14356),
#  ('-t', 14314),
#  ('implicitly', 14303),
#  ('Computing', 14300),
#  ('Standard', 14294),
#  ("'S", 14242),
#  ('linked', 14227),
#  ('ONVIF', 14210),
#  ('inside', 14207),
#  ('grid', 14207),
#  ('intended', 14202),
#  ('mask', 14201),
#  ('handling', 14170),
#  ('__x', 14162),
#  ('mm', 14161),
#  ('Now', 14160),
#  ('1995', 14157),
#  ('optimizations', 14132),
#  ('Fortran', 14102),
#  ('others', 14094),
#  ('z', 14067),
#  ('WI', 14059),
#  ('V2', 14049),
#  ('warn', 14041),
#  ('r', 14040),
#  ('namespace', 14031),
#  ('parent', 14002),
#  ('B21', 13986),
#  ('thus', 13963),
#  ('typically', 13950),
#  ('stores', 13907),
#  ('pentagonal', 13905),
#  ('NOTE', 13904),
#  ('KD+1', 13882),
#  ('-r', 13878),
#  ('ISPLIT', 13875),
#  ('cubemap', 13861),
#  ('enough', 13847),
#  ('simply', 13840),
#  ('I/O', 13827),
#  ('AUTHORS', 13824),
#  ('right-hand', 13824),
#  ('METHODS', 13803),
#  ('tests', 13787),
#  ('bug', 13786),
#  ('val', 13769),
#  ('high', 13768),
#  ('Option', 13763),
#  ('LATIN', 13746),
#  ('-IPIV', 13740),
#  ('mapped', 13739),
#  ('LOGICAL', 13739),
#  (':Types', 13736),
#  ('bitmap', 13728),
#  ('treated', 13711),
#  ('Usage', 13709),
#  ('terminated', 13678),
#  ('received', 13672),
#  ('GIVCOL', 13638),
#  ('sequences', 13633),
#  ('wait', 13627),
#  ('priority', 13594),
#  ('bar', 13590),
#  ('o', 13584),
#  ('launch', 13567),
#  ('marked', 13558),
#  ('pivot', 13556),
#  ('clock', 13555),
#  ('classes', 13551),
#  ('sqrt', 13534),
#  ('dir', 13523),
#  ('IJOB', 13512),
#  ('Memory', 13509),
#  ('arithmetic', 13508),
#  ('Block', 13494),
#  ('beginning', 13470),
#  ('button', 13443),
#  ('-10', 13420),
#  ('errno', 13413),
#  ('off-diagonal', 13411),
#  ('generating', 13410),
#  ('Givens', 13404),
#  ('products', 13397),
#  ('-n', 13384),
#  ('compact', 13379),
#  ('items', 13372),
#  ('Frobenius', 13361),
#  ('launches', 13355),
#  ('Right', 13348),
#  ('according', 13341),
#  ('—', 13311),
#  ('dump', 13306),
#  ('IHIZ', 13306),
#  ('property', 13302),
#  ('Mail', 13289),
#  ('num', 13288),
#  ('headers', 13281),
#  ('video', 13270),
#  ('steps', 13265),
#  ('records', 13249),
#  ('reading', 13243),
#  ('Report', 13231),
#  ('split', 13229),
#  ('EQUED', 13218),
#  ('VALUE', 13188),
#  ('searched', 13176),
#  ('t', 13171),
#  ('Defaults', 13159),
#  ('compatible', 13148),
#  ('SCALE', 13136),
#  ('GIVNUM', 13120),
#  ('rule', 13113),
#  ('Left', 13106),
#  ('problems', 13101),
#  ('know', 13098),
#  ('unique', 13075),
#  ('increment', 13066),
#  ('properties', 13039),
#  ('remaining', 13036),
#  ('caca_canvas_t', 12998),
#  ('utility', 12996),
#  ('assume', 12995),
#  ('association', 12967),
#  ('secular', 12967),
#  ('checking', 12956),
#  ('Output', 12950),
#  ('*j/2', 12948),
#  ('Value', 12939),
#  ('daemon', 12898),
#  ('man', 12870),
#  ('l', 12854),
#  ('I-th', 12851),
#  ('peer', 12844),
#  ('conjugate-transpose', 12840),
#  ('again', 12836),
#  ('expressions', 12824),
#  ('refinement', 12811),
#  ('indicated', 12798),
#  ('-a', 12795),
#  ('TODO', 12780),
#  ('blocksize', 12776),
#  ('suffix', 12756),
#  ('operator', 12721),
#  ('KB', 12718),
#  ('-I', 12713),
#  ('chosen', 12710),
#  ('-by-', 12706),
#  ('ARF', 12686),
#  ('ensure', 12682),
#  ('N1', 12671),
#  ('entire', 12670),
#  ('public', 12666),
#  ('IEEE', 12664),
#  ('fixed', 12644),
#  ('tags', 12605),
#  ('NOTES', 12593),
#  ('solves', 12590),
#  ('core', 12577),
#  ('CHARACTER', 12577),
#  ('title', 12576),
#  ('V1', 12570),
#  ('good', 12566),
#  ('PERM', 12566),
#  ('best', 12543),
#  ('Functions', 12536),
#  ('hexadecimal', 12497),
#  ('units', 12487),
#  ('ILOZ', 12475),
#  ('prevent', 12460),
#  ('force', 12435),
#  ('controls', 12400),
#  ('Before', 12400),
#  ('canvas', 12377),
#  ('nonzero', 12370),
#  ('connect', 12369),
#  ('List', 12360),
#  ('GIVPTR', 12352),
#  ('MB', 12339),
#  ('writes', 12338),
#  ('FTP', 12328),
#  ('Using', 12325),
#  ('Read', 12311),
#  ('paths', 12302),
#  ('shift', 12298),
#  ('cudaError_t', 12289),
#  ('iterations', 12278),
#  ('save', 12255),
#  ('across', 12251),
#  ('produce', 12247),
#  ('modification', 12232),
#  ('adds', 12228),
#  ('few', 12212),
#  ('**H', 12211),
#  ('obj-', 12180),
#  ('EXAMPLES', 12170),
#  ('better', 12167),
#  ('digits', 12167),
#  ('*handle', 12162),
#  ('gives', 12142),
#  ('References', 12141),
#  ('D.', 12136),
#  ('accept', 12108),
#  ('proxy', 12106),
#  ('encoded', 12106),
#  ('sign', 12080),
#  ('Reference', 12076),
#  ('2*N', 12038),
#  ('packets', 12034),
#  ('Thus', 12012),
#  ('iteration', 11992),
#  ('scheme', 11972),
#  ('creating', 11947),
#  ('Foundation', 11943),
#  ('NL', 11943),
#  ('LDWORK', 11925),
#  ('V2T', 11914),
#  ('encountered', 11906),
#  ('token', 11898),
#  ('System', 11866),
#  ('depending', 11853),
#  ('reads', 11840),
#  ('Definition', 11827),
#  ('converted', 11818),
#  ('guaranteed', 11813),
#  ('child', 11803),
#  ('MIN', 11803),
#  ('something', 11788),
#  ('however', 11767),
#  ('security', 11754),
#  ('-O', 11753),
#  ('buf', 11751),
#  ('directive', 11747),
#  ('CS', 11717),
#  ('underflow', 11715),
#  ('SMALL', 11697),
#  ('view', 11690),
#  ('Packed', 11672),
#  ('DIFR', 11668),
#  ('gcc', 11638),
#  ('WANTT', 11611),
#  ('doing', 11605),
#  ('actions', 11588),
#  ('Test', 11585),
#  ('executing', 11584),
#  ('ldc', 11578),
#  ('ratio', 11559),
#  ('generic', 11544),
#  ('placed', 11539),
#  ('ERR_BNDS_COMP', 11538),
#  ('embedded', 11525),
#  ('HTTP', 11499),
#  ('linking', 11478),
#  ('speed', 11470),
#  ('sure', 11468),
#  ('ISUPPZ', 11464),
#  ('.TRUE.', 11464),
#  ('SCOND', 11461),
#  ('completion', 11452),
#  ('mapping', 11449),
#  ('operating', 11415),
#  ('e.g.', 11399),
#  ('RANGE=', 11396),
#  ('A**T', 11395),
#  ('functionality', 11380),
#  ('1D', 11375),
#  ('divide', 11370),
#  ('keep', 11356),
#  ('de', 11341),
#  ('WR', 11325),
#  ('tools', 11319),
#  ('passes', 11287),
#  ('nothing', 11282),
#  ('tables', 11276),
#  ('_Traits', 11268),
#  ('segment', 11267),
#  ('shown', 11262),
#  ('runs', 11235),
#  ('install', 11216),
#  ('R.', 11208),
#  ('native', 11192),
#  ('BIO', 11187),
#  ('ERR_BNDS_NORM', 11177),
#  ('accepted', 11173),
#  ('identity', 11170),
#  ('covers', 11165),
#  ('SVD', 11165),
#  ('Doxygen', 11162),
#  ('YET', 11129),
#  ('history', 11126),
#  ('appears', 11115),
#  ('raw', 11110),
#  ('LDU2', 11110),
#  ('approximate', 11099),
#  ('partial', 11091),
#  ('generally', 11078),
#  ('-e', 11069),
#  ('DOCUMENTED', 11055),
#  ('nq', 11053),
#  ('behaviour', 11045),
#  ('RHO', 11044),
#  ('globus_bool_t', 11032),
#  ('n2', 11030),
#  ('computation', 11026),
#  ('often', 11020),
#  ('Division', 11019),
#  ('meaning', 11005),
#  ('parse', 10998),
#  ('audio', 10990),
#  ('factored', 10985),
#  ('pixels', 10984),
#  ('-O2', 10982),
#  ('multipliers', 10972),
#  ('convenience', 10958),
#  ('Then', 10955),
#  ('IO', 10954),
#  ('affect', 10934),
#  ('destroyed', 10933),
#  ('subsequent', 10925),
#  ('rank', 10915),
#  ('compiling', 10914),
#  ('tail', 10889),
#  ('stop', 10880),
#  ('implies', 10880),
#  ('Open', 10872),
#  ('notice', 10844),
#  ('POSIX', 10824),
#  ('8-bit', 10824),
#  ('XTRUE', 10814),
#  ('chain', 10807),
#  ('ABSTOL', 10806),
#  ('individual', 10800),
#  ('upon', 10799),
#  ('selection', 10796),
#  ('*e', 10793),
#  ('consecutive', 10788),
#  ('layers', 10772),
#  ('mail', 10771),
#  ('Types', 10768),
#  ('globus_ftp_client_handle_t', 10767),
#  ('likely', 10760),
#  ('JOBU', 10752),
#  ('blocked', 10738),
#  ('links', 10724),
#  ('reported', 10709),
#  ('copyright', 10708),
#  ('solve', 10707),
#  ('Pointer', 10700),
#  ('subject', 10694),
#  ('Conjugate', 10692),
#  ('outside', 10676),
#  ('faster', 10668),
#  ('newer', 10649),
#  ('Currently', 10646),
#  ('J.', 10642),
#  ('UV', 10642),
#  ('constants', 10641),
#  ('dst', 10641),
#  ('OR', 10637),
#  ('globus_ftp_client_operationattr_t', 10607),
#  ('PL', 10599),
#  ('uint16_t', 10587),
#  ('built-in', 10584),
#  ('MV', 10576),
#  ('startup', 10571),
#  ('built', 10563),
#  ('scripts', 10554),
#  ('Disable', 10540),
#  ('web', 10538),
#  ('packages', 10535),
#  ('*ctx', 10529),
#  ('corresponds', 10528),
#  ('Contains', 10527),
#  ('User', 10522),
#  ('turn', 10520),
#  ('whenever', 10504),
#  ('things', 10483),
#  ('ones', 10476),
#  ('*abs', 10458),
#  ('beta', 10449),
#  ('lambda', 10435),
#  ('preferred', 10424),
#  ('detected', 10406),
#  ('P**T', 10404),
#  ('almost', 10401),
#  ('multiplies', 10385),
#  ('i-1', 10380),
#  ('initialization', 10367),
#  ('disables', 10364),
#  ('TAUP1', 10360),
#  ('TAUP2', 10360),
#  ('TAUQ1', 10360),
#  ('0:4,0:2', 10360),
#  ('graph', 10358),
#  ('unexpected', 10339),
#  ('‘', 10327),
#  ('fast', 10324),
#  ('PR', 10312),
#  ('correspond', 10307),
#  ('implementations', 10298),
#  ('prints', 10287),
#  ('ascending', 10285),
#  ('lock', 10282),
#  ('2013', 10280),
#  ('game', 10278),
#  ('-b', 10276),
#  ('probably', 10262),
#  ('correctly', 10251),
#  ('starts', 10237),
#  ('allocate', 10222),
#  ('Title', 10220),
#  ('license', 10206),
#  ('\\n', 10181),
#  ('stdout', 10176),
#  ('ARGUMENTS', 10167),
#  ('freed', 10163),
#  ('B22', 10158),
#  ('OF', 10155),
#  ('LDVT', 10154),
#  ('1.0', 10153),
#  ('M-by-M', 10132),
#  ('reply', 10114),
#  ('identical', 10101),
#  ('ldt', 10096),
#  ('body', 10077),
#  ('Class', 10062),
#  ('cipher', 10058),
#  ('PARAMS', 10055),
#  ('pixel', 10054),
#  ('servers', 10053),
#  ('stderr', 10047),
#  ('Full', 10042),
#  ('args', 10036),
#  ('master', 10032),
#  ('optimum', 10031),
#  ('THE', 10025),
#  ('L1', 10022),
#  ('U*D*U**T', 10009),
#  ('division', 9991),
#  ('str', 9991),
#  ('creation', 9989),
#  ('copied', 9981),
#  ('some_value', 9979),
#  ('.TRUE', 9978),
#  ('contained', 9954),
#  ('whole', 9946),
#  ('omitted', 9937),
#  ('addressing', 9918),
#  ('produced', 9915),
#  ('statistics', 9911),
#  ('PowerPC', 9909),
#  ('Perform', 9906),
#  ('err', 9904),
#  ('Q*C', 9889),
#  ('ASCII', 9886),
#  ('tries', 9882),
#  ('underlying', 9875),
#  ('computing', 9874),
#  ('configure', 9847),
#  ('NSWEEP', 9842),
#  ('refer', 9837),
#  ('nor', 9815),
#  ('similarity', 9808),
#  ('intermediate', 9804),
#  ('invariant', 9793),
#  ('effects', 9766),
#  ('NS', 9763),
#  ('processors', 9762),
#  ('comment', 9750),
#  ('minor', 9749),
#  ('=min', 9745),
#  ('safe', 9744),
#  ('differs', 9736),
#  ('B2', 9720),
#  ('0.0', 9718),
#  ('ld', 9713),
#  ('limited', 9709),
#  ('mechanism', 9705),
#  ('None', 9701),
#  ('implement', 9682),
#  ('describes', 9677),
#  ('superdiagonals', 9676),
#  ('FILES', 9675),
#  ('though', 9673),
#  ('Matrix', 9673),
#  ('trace', 9660),
#  ('boundary', 9652),
#  ('Other', 9651),
#  ('credential', 9639),
#  ('older', 9629),
#  ('ELF', 9629),
#  ('metadata', 9622),
#  ('*x', 9622),
#  ('mouse', 9621),
#  ('hostname', 9612),
#  ('2n-j', 9600),
#  ('sorted', 9590),
#  ('numeric', 9589),
#  ('ldab', 9588),
#  ('leaves', 9586),
#  ('Detailed', 9581),
#  ('backend', 9571),
#  ('programming', 9570),
#  ('NR', 9567),
#  ('effective', 9565),
#  ('import', 9551),
#  ('blocking', 9548),
#  ('trailing', 9546),
#  ('TCP', 9540),
#  ('-Wall', 9536),
#  ('angles', 9524),
#  ('Objective-C', 9507),
#  ('adding', 9501),
#  ('plus', 9493),
#  ('loops', 9486),
#  ('LDGCOL', 9480),
#  ('wrapper', 9479),
#  ('assigned', 9474),
#  ('conditions', 9473),
#  ('coordinates', 9473),
#  ('having', 9472),
#  ('While', 9460),
#  ('Enabled', 9460),
#  ('arbitrary', 9458),
#  ('Group', 9451),
#  ('MPI', 9449),
#  ('retrieve', 9446),
#  ('A**H', 9425),
#  ...]

# %%
zip_words = [each[0] for each in zip_list]
zip_words
# Out:
# ['minimum',
#  'common',
#  'With',
#  'Cholesky',
#  'optimization',
#  'service',
#  'box',
#  'Q**H',
#  'password',
#  'extensions',
#  'distribution',
#  '25',
#  'signal',
#  'LDX11',
#  'syntax',
#  'virtual',
#  'declared',
#  'final',
#  'Format',
#  'active',
#  'square',
#  'copies',
#  'estimates',
#  'One',
#  'targets',
#  'initial',
#  'certificate',
#  'logical',
#  'routines',
#  'language',
#  'model',
#  'head',
#  'LDX21',
#  'successfully',
#  'removed',
#  'addresses',
#  'separate',
#  'queue',
#  'pattern',
#  'Any',
#  '”',
#  'BERR',
#  '-h',
#  'U1',
#  'sections',
#  'longer',
#  'U2',
#  'XML',
#  'destination',
#  'JOBV',
#  'shell',
#  'ICOMPQ',
#  'hardware',
#  '“',
#  '-s',
#  'permutation',
#  'compilation',
#  'now',
#  'Science',
#  'Q**T',
#  'LDH',
#  'causes',
#  'Function',
#  'Documentation',
#  'perform',
#  'p',
#  'record',
#  'floating',
#  'normally',
#  'threads',
#  "R'",
#  'MM',
#  'converge',
#  'B11',
#  'actually',
#  'j+1',
#  'FERR',
#  'matching',
#  'trapezoid',
#  'occur',
#  'TOL',
#  'obtained',
#  'appropriate',
#  '0x02',
#  'implemented',
#  'necessary',
#  'foo',
#  'select',
#  'equation',
#  'disabled',
#  'executed',
#  'rotation',
#  'LDVL',
#  'LDVR',
#  'completed',
#  '-o',
#  '-c',
#  'J',
#  'disable',
#  'member',
#  'DIRECT',
#  'configured',
#  'failure',
#  'Software',
#  'Also',
#  'codes',
#  'else',
#  'close',
#  'obtain',
#  'tool',
#  'etc',
#  '-v',
#  'architecture',
#  'filesystem',
#  'DIF',
#  'around',
#  '2008',
#  'optionally',
#  '35',
#  'region',
#  'domain',
#  'NOT',
#  'ENGINE',
#  'formats',
#  'BUGS',
#  'taken',
#  'various',
#  'modules',
#  'typename',
#  'uint32_t',
#  'show',
#  'As',
#  'occurred',
#  'avoid',
#  'against',
#  'Range',
#  'Extended',
#  'non-zero',
#  'replaced',
#  'WANTZ',
#  'len',
#  'Please',
#  'shall',
#  'UTC',
#  'allocation',
#  'much',
#  '-d',
#  'never',
#  'M.',
#  '64',
#  'RETURN',
#  'external',
#  '16',
#  'short',
#  'verbose',
#  'depth',
#  'processing',
#  'conjugate',
#  'null',
#  'url',
#  'Version',
#  'certain',
#  'handler',
#  'users',
#  'indicate',
#  'applications',
#  'Level',
#  'matches',
#  'op',
#  'archive',
#  'word',
#  'known',
#  'require',
#  'Used',
#  '-f',
#  'Sets',
#  'appear',
#  '45',
#  'HTML',
#  'diag',
#  'listed',
#  'components',
#  'considered',
#  'extra',
#  'works',
#  'therefore',
#  'f',
#  'Data',
#  'terminal',
#  'exist',
#  'sent',
#  'move',
#  'channels',
#  'undefined',
#  'Computer',
#  'OpenSSL',
#  'warnings',
#  'own',
#  'uint8_t',
#  '53',
#  'decomposition',
#  'gets',
#  'unblocked',
#  'dynamic',
#  'Some',
#  'conversion',
#  'installed',
#  'item',
#  'did',
#  'attempt',
#  '9',
#  'together',
#  'executable',
#  'Let',
#  'VECT',
#  'session',
#  'addition',
#  'IU',
#  'IL',
#  'checks',
#  'config',
#  'events',
#  'Transpose',
#  'Debian',
#  'restart',
#  'higher',
#  'exact',
#  'ABI',
#  'ISO',
#  'represents',
#  'suitable',
#  '1-by-1',
#  'printf',
#  'project',
#  'cluster',
#  'release',
#  'fails',
#  'generation',
#  '54',
#  'area',
#  'inline',
#  'perl',
#  'holds',
#  'macros',
#  'LETTER',
#  '-p',
#  'component',
#  'V.',
#  'needs',
#  'processes',
#  'arg',
#  'alignment',
#  'interchanged',
#  'magnitude',
#  'invoked',
#  'COMPQ',
#  'features',
#  'componentwise',
#  'several',
#  'smaller',
#  'Jacobi',
#  'nvmlReturn_t',
#  'parts',
#  'They',
#  'immediately',
#  'resources',
#  'DECLDIR',
#  'LRWORK',
#  'pages',
#  'scaled',
#  'build',
#  'processor',
#  'actual',
#  'requests',
#  'odd',
#  '_',
#  '2017',
#  'fail',
#  'infinity',
#  'AND',
#  'compatibility',
#  'indices',
#  'IP',
#  'asynchronous',
#  'sum',
#  'creates',
#  'displayed',
#  'SQRE',
#  'working',
#  'Q2',
#  'pointers',
#  'interchanges',
#  'src',
#  'reduces',
#  'separated',
#  'previously',
#  'undef',
#  'date',
#  '1,2',
#  'depends',
#  'accepts',
#  'specifying',
#  'assembler',
#  'consider',
#  'put',
#  'rules',
#  'enables',
#  'Deprecated',
#  'AMAX',
#  'occurs',
#  'ANORM',
#  'bool',
#  'regular',
#  'forward',
#  'e',
#  'sides',
#  'branch',
#  'P2',
#  'alpha',
#  'nvmlDevice_t',
#  'Type',
#  'exception',
#  'exists',
#  'let',
#  'Tcl',
#  'CNORM',
#  '0x00',
#  'references',
#  'layered',
#  'Free',
#  'Public',
#  'LDAF',
#  'indicating',
#  'plane',
#  'scheduling',
#  'n-1',
#  'bottom',
#  'response',
#  'cursor',
#  'definite',
#  'Show',
#  'INCY',
#  '05',
#  'Generated',
#  'AF',
#  'remove',
#  'compressed',
#  'try',
#  'timeout',
#  'font',
#  'n1',
#  'settings',
#  'P1',
#  'Unchanged',
#  'old',
#  'bus',
#  'LICENSE',
#  '3D',
#  'pointed',
#  'CUresult',
#  'General',
#  'four',
#  'continue',
#  'future',
#  'V1T',
#  '64-bit',
#  'along',
#  'policy',
#  'preprocessor',
#  'machines',
#  'Name',
#  '16-bit',
#  'printed',
#  'nodes',
#  'amount',
#  'SCREEN*',
#  'SEP',
#  'VT',
#  'Description',
#  'LAPACK',
#  'fully',
#  'packet',
#  'modes',
#  'columnwise',
#  'disk',
#  'orthonormal',
#  'step',
#  'due',
#  'accuracy',
#  'loaded',
#  'estimated',
#  'descriptor',
#  'pivoting',
#  '**',
#  'procedure',
#  'BLAS',
#  'File',
#  'connections',
#  'locale',
#  'definition',
#  'down',
#  'Z.',
#  'style',
#  'caller',
#  'Since',
#  'compile',
#  'execute',
#  'random',
#  'distributed',
#  'No-op',
#  'reduce',
#  'volume',
#  '0x04',
#  'comments',
#  'redistribute',
#  'convert',
#  'decimal',
#  'includes',
#  'receive',
#  'authentication',
#  'yet',
#  'writing',
#  'command-line',
#  'followed',
#  'O',
#  '-l',
#  'look',
#  'delete',
#  'Add',
#  'H.',
#  '//',
#  'Windows',
#  'specification',
#  'chtype',
#  '==',
#  'expected',
#  'power',
#  'Net',
#  'label',
#  'resulting',
#  'structures',
#  'forms',
#  'profile',
#  'images',
#  'note',
#  'levels',
#  'examples',
#  '-m',
#  'alias',
#  'able',
#  'Here',
#  'correct',
#  '100',
#  'kind',
#  'pairs',
#  'submatrix',
#  'words',
#  'private',
#  '=n',
#  'squares',
#  'Number',
#  'Create',
#  'superdiagonal',
#  '_CharT',
#  'EPS',
#  'Error',
#  'lists',
#  'hold',
#  'override',
#  'recommended',
#  'processed',
#  'statement',
#  'basic',
#  'background',
#  '-t',
#  'implicitly',
#  'Computing',
#  'Standard',
#  "'S",
#  'linked',
#  'ONVIF',
#  'inside',
#  'grid',
#  'intended',
#  'mask',
#  'handling',
#  '__x',
#  'mm',
#  'Now',
#  '1995',
#  'optimizations',
#  'Fortran',
#  'others',
#  'z',
#  'WI',
#  'V2',
#  'warn',
#  'r',
#  'namespace',
#  'parent',
#  'B21',
#  'thus',
#  'typically',
#  'stores',
#  'pentagonal',
#  'NOTE',
#  'KD+1',
#  '-r',
#  'ISPLIT',
#  'cubemap',
#  'enough',
#  'simply',
#  'I/O',
#  'AUTHORS',
#  'right-hand',
#  'METHODS',
#  'tests',
#  'bug',
#  'val',
#  'high',
#  'Option',
#  'LATIN',
#  '-IPIV',
#  'mapped',
#  'LOGICAL',
#  ':Types',
#  'bitmap',
#  'treated',
#  'Usage',
#  'terminated',
#  'received',
#  'GIVCOL',
#  'sequences',
#  'wait',
#  'priority',
#  'bar',
#  'o',
#  'launch',
#  'marked',
#  'pivot',
#  'clock',
#  'classes',
#  'sqrt',
#  'dir',
#  'IJOB',
#  'Memory',
#  'arithmetic',
#  'Block',
#  'beginning',
#  'button',
#  '-10',
#  'errno',
#  'off-diagonal',
#  'generating',
#  'Givens',
#  'products',
#  '-n',
#  'compact',
#  'items',
#  'Frobenius',
#  'launches',
#  'Right',
#  'according',
#  '—',
#  'dump',
#  'IHIZ',
#  'property',
#  'Mail',
#  'num',
#  'headers',
#  'video',
#  'steps',
#  'records',
#  'reading',
#  'Report',
#  'split',
#  'EQUED',
#  'VALUE',
#  'searched',
#  't',
#  'Defaults',
#  'compatible',
#  'SCALE',
#  'GIVNUM',
#  'rule',
#  'Left',
#  'problems',
#  'know',
#  'unique',
#  'increment',
#  'properties',
#  'remaining',
#  'caca_canvas_t',
#  'utility',
#  'assume',
#  'association',
#  'secular',
#  'checking',
#  'Output',
#  '*j/2',
#  'Value',
#  'daemon',
#  'man',
#  'l',
#  'I-th',
#  'peer',
#  'conjugate-transpose',
#  'again',
#  'expressions',
#  'refinement',
#  'indicated',
#  '-a',
#  'TODO',
#  'blocksize',
#  'suffix',
#  'operator',
#  'KB',
#  '-I',
#  'chosen',
#  '-by-',
#  'ARF',
#  'ensure',
#  'N1',
#  'entire',
#  'public',
#  'IEEE',
#  'fixed',
#  'tags',
#  'NOTES',
#  'solves',
#  'core',
#  'CHARACTER',
#  'title',
#  'V1',
#  'good',
#  'PERM',
#  'best',
#  'Functions',
#  'hexadecimal',
#  'units',
#  'ILOZ',
#  'prevent',
#  'force',
#  'controls',
#  'Before',
#  'canvas',
#  'nonzero',
#  'connect',
#  'List',
#  'GIVPTR',
#  'MB',
#  'writes',
#  'FTP',
#  'Using',
#  'Read',
#  'paths',
#  'shift',
#  'cudaError_t',
#  'iterations',
#  'save',
#  'across',
#  'produce',
#  'modification',
#  'adds',
#  'few',
#  '**H',
#  'obj-',
#  'EXAMPLES',
#  'better',
#  'digits',
#  '*handle',
#  'gives',
#  'References',
#  'D.',
#  'accept',
#  'proxy',
#  'encoded',
#  'sign',
#  'Reference',
#  '2*N',
#  'packets',
#  'Thus',
#  'iteration',
#  'scheme',
#  'creating',
#  'Foundation',
#  'NL',
#  'LDWORK',
#  'V2T',
#  'encountered',
#  'token',
#  'System',
#  'depending',
#  'reads',
#  'Definition',
#  'converted',
#  'guaranteed',
#  'child',
#  'MIN',
#  'something',
#  'however',
#  'security',
#  '-O',
#  'buf',
#  'directive',
#  'CS',
#  'underflow',
#  'SMALL',
#  'view',
#  'Packed',
#  'DIFR',
#  'gcc',
#  'WANTT',
#  'doing',
#  'actions',
#  'Test',
#  'executing',
#  'ldc',
#  'ratio',
#  'generic',
#  'placed',
#  'ERR_BNDS_COMP',
#  'embedded',
#  'HTTP',
#  'linking',
#  'speed',
#  'sure',
#  'ISUPPZ',
#  '.TRUE.',
#  'SCOND',
#  'completion',
#  'mapping',
#  'operating',
#  'e.g.',
#  'RANGE=',
#  'A**T',
#  'functionality',
#  '1D',
#  'divide',
#  'keep',
#  'de',
#  'WR',
#  'tools',
#  'passes',
#  'nothing',
#  'tables',
#  '_Traits',
#  'segment',
#  'shown',
#  'runs',
#  'install',
#  'R.',
#  'native',
#  'BIO',
#  'ERR_BNDS_NORM',
#  'accepted',
#  'identity',
#  'covers',
#  'SVD',
#  'Doxygen',
#  'YET',
#  'history',
#  'appears',
#  'raw',
#  'LDU2',
#  'approximate',
#  'partial',
#  'generally',
#  '-e',
#  'DOCUMENTED',
#  'nq',
#  'behaviour',
#  'RHO',
#  'globus_bool_t',
#  'n2',
#  'computation',
#  'often',
#  'Division',
#  'meaning',
#  'parse',
#  'audio',
#  'factored',
#  'pixels',
#  '-O2',
#  'multipliers',
#  'convenience',
#  'Then',
#  'IO',
#  'affect',
#  'destroyed',
#  'subsequent',
#  'rank',
#  'compiling',
#  'tail',
#  'stop',
#  'implies',
#  'Open',
#  'notice',
#  'POSIX',
#  '8-bit',
#  'XTRUE',
#  'chain',
#  'ABSTOL',
#  'individual',
#  'upon',
#  'selection',
#  '*e',
#  'consecutive',
#  'layers',
#  'mail',
#  'Types',
#  'globus_ftp_client_handle_t',
#  'likely',
#  'JOBU',
#  'blocked',
#  'links',
#  'reported',
#  'copyright',
#  'solve',
#  'Pointer',
#  'subject',
#  'Conjugate',
#  'outside',
#  'faster',
#  'newer',
#  'Currently',
#  'J.',
#  'UV',
#  'constants',
#  'dst',
#  'OR',
#  'globus_ftp_client_operationattr_t',
#  'PL',
#  'uint16_t',
#  'built-in',
#  'MV',
#  'startup',
#  'built',
#  'scripts',
#  'Disable',
#  'web',
#  'packages',
#  '*ctx',
#  'corresponds',
#  'Contains',
#  'User',
#  'turn',
#  'whenever',
#  'things',
#  'ones',
#  '*abs',
#  'beta',
#  'lambda',
#  'preferred',
#  'detected',
#  'P**T',
#  'almost',
#  'multiplies',
#  'i-1',
#  'initialization',
#  'disables',
#  'TAUP1',
#  'TAUP2',
#  'TAUQ1',
#  '0:4,0:2',
#  'graph',
#  'unexpected',
#  '‘',
#  'fast',
#  'PR',
#  'correspond',
#  'implementations',
#  'prints',
#  'ascending',
#  'lock',
#  '2013',
#  'game',
#  '-b',
#  'probably',
#  'correctly',
#  'starts',
#  'allocate',
#  'Title',
#  'license',
#  '\\n',
#  'stdout',
#  'ARGUMENTS',
#  'freed',
#  'B22',
#  'OF',
#  'LDVT',
#  '1.0',
#  'M-by-M',
#  'reply',
#  'identical',
#  'ldt',
#  'body',
#  'Class',
#  'cipher',
#  'PARAMS',
#  'pixel',
#  'servers',
#  'stderr',
#  'Full',
#  'args',
#  'master',
#  'optimum',
#  'THE',
#  'L1',
#  'U*D*U**T',
#  'division',
#  'str',
#  'creation',
#  'copied',
#  'some_value',
#  '.TRUE',
#  'contained',
#  'whole',
#  'omitted',
#  'addressing',
#  'produced',
#  'statistics',
#  'PowerPC',
#  'Perform',
#  'err',
#  'Q*C',
#  'ASCII',
#  'tries',
#  'underlying',
#  'computing',
#  'configure',
#  'NSWEEP',
#  'refer',
#  'nor',
#  'similarity',
#  'intermediate',
#  'invariant',
#  'effects',
#  'NS',
#  'processors',
#  'comment',
#  'minor',
#  '=min',
#  'safe',
#  'differs',
#  'B2',
#  '0.0',
#  'ld',
#  'limited',
#  'mechanism',
#  'None',
#  'implement',
#  'describes',
#  'superdiagonals',
#  'FILES',
#  'though',
#  'Matrix',
#  'trace',
#  'boundary',
#  'Other',
#  'credential',
#  'older',
#  'ELF',
#  'metadata',
#  '*x',
#  'mouse',
#  'hostname',
#  '2n-j',
#  'sorted',
#  'numeric',
#  'ldab',
#  'leaves',
#  'Detailed',
#  'backend',
#  'programming',
#  'NR',
#  'effective',
#  'import',
#  'blocking',
#  'trailing',
#  'TCP',
#  '-Wall',
#  'angles',
#  'Objective-C',
#  'adding',
#  'plus',
#  'loops',
#  'LDGCOL',
#  'wrapper',
#  'assigned',
#  'conditions',
#  'coordinates',
#  'having',
#  'While',
#  'Enabled',
#  'arbitrary',
#  'Group',
#  'MPI',
#  'retrieve',
#  'A**H',
#  ...]

# %%
with open(global_dir + 'zip_words.txt','w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)

    for word in zip_words:
        csv_writer.writerow([word])
